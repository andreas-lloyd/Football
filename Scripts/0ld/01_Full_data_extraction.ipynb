# %% [markdown]
# # Full data extraction
#
# This is the script where the full data extraction should be done without the need to run various scripts. All the functions will be taken from the *football_functions* package and nothing else should need to be imported.
#
# There are several key features to these functions in the way that they save and pull HTML - almost all of them need the current date and proxy to be provided. This is done so that a proxy can easily be dealt with and any date of choice can be used (to go back and fix old data).
#
# Note that they will all also ask for paths - this is done so that switching between OS should not be difficult. To that end the system of *HOME_PATH* is also used, such that all paths are dependent on the *HOME_PATH* and only it should need to be modified, as long as the file structure is followed.
#
# The important structure is as follows
#
# /Data/
#
#     00_Organisation/
#     01_HTML/
#     02_Stories/
#
# Within each one you will find the domain name as well as the date it was extracted on - and subfolders indicating different processes (such as *base link* or *sublink*).
#
# The process is as follows:
#
#     1) Pull the HTML from the baselinks (depends on generic.pull_html)
#     2) Find the sublinks within certain pages of the baselinks, as some are, for example, team pages (depends on source_specific)
#     3) Scrape all the sublinks found to get our "main pages" for the scraping of headlines (depends on generic.pull_html)
#     4) Find the headlines within the scraped sublinks, saving information about the article and any easy extras (like image titles or summaries) in order to better tag later (depends on source_specific)
#     5) Scrape the headline URL found in the previous step in order to get the story's HTML for story extraction (depends on generic.pull_html)
#     6) Get the actual story from the HTML and save it along with the other information *NOT COMPLETE*
#
# Steps depending on *generic.pull_html* will save .HTML files in *Data/01_HTML*. Step 2 saves links in a list under *Data/00_Organisation*, and step 4 saves .pickle files with dictionaries for each story under */Data/02_Stories*.

# %% [markdown]
# ## Block 1: Initial constants
#
# Some initial constants just for the initial overhead, only this should need to be modified

# %%
# Base functions for running the script
import sys, datetime

# Set the path and proxy in accordance with our OS
if sys.platform == 'linux':
    HOME_PATH = '/home/andreas/Desktop/Projects/Football/'
    proxy_settings = None
else:
    HOME_PATH = 'c:/Users/amathewl/Desktop/03_Personal_projects/football/'
    proxy_settings = None
    
# Relative paths
html_loc = HOME_PATH + 'Data/01_HTML/'
organ_loc = HOME_PATH + 'Data/00_Organisation/'
story_loc = HOME_PATH + 'Data/02_Stories/'

# Files to find
baseurl_loc = organ_loc + 'news_sources.txt'

# Get today's date for various functions
date_today = datetime.datetime.today().strftime('%Y_%m_%d')

# %% [markdown]
# ## Block 2: Importing from football_functions
#
# The personal functions we will use from football_functions for the initial processes. Have separated this because could cause some issues when changes are made.

# %%
# Base URLs
from football_functions.processes.html_extraction import baseurls

# Suburls
from football_functions.processes.html_extraction import suburls

# Headlines
from football_functions.processes.information_extraction import headlines

# Stories
from football_functions.processes.information_extraction import stories

# %% [markdown]
# ## Block 3: Baseline URL extraction
#
# Getting the HTML from the baseline URLs and saving to file

# %%
baseline_errors = baseurls.scrape_urls(baseurl_loc, html_loc, date_today, proxy_settings)
# Out:
# Loading URLs from /home/andreas/Desktop/Projects/Football/Data/00_Organisation/news_sources.txt
# Successfully pulled HTML from http://www.bbc.com/sport/football/teams
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/bbc/2018_01_27/base_urls/sport_football_teams.html
# Making directory /home/andreas/Desktop/Projects/Football/Data/01_HTML/bbc/2018_01_27/base_urls/
# Successfully saved URL
#
# Successfully pulled HTML from http://www.bbc.com/sport/football/transfers
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/bbc/2018_01_27/base_urls/sport_football_transfers.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.dailymail.co.uk/sport/premierleague/index.html
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/dailymail/2018_01_27/base_urls/sport_premierleague_indexhtml.html
# Making directory /home/andreas/Desktop/Projects/Football/Data/01_HTML/dailymail/2018_01_27/base_urls/
# Successfully saved URL
#
# Successfully pulled HTML from http://www.dailymail.co.uk/sport/football/index.html
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/dailymail/2018_01_27/base_urls/sport_football_indexhtml.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/teams
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/base_urls/football_teams.html
# Making directory /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/base_urls/
# Successfully saved URL
#
# Successfully pulled HTML from http://www.mirror.co.uk/sport/football/
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/base_urls/sport_football_.html
# Making directory /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/base_urls/
# Successfully saved URL
#
# Successfully pulled HTML from http://www.skysports.com/football/transfer-paper-talk-regional
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/skysports/2018_01_27/base_urls/football_transferpapertalkregional.html
# Making directory /home/andreas/Desktop/Projects/Football/Data/01_HTML/skysports/2018_01_27/base_urls/
# Successfully saved URL
#
# Successfully pulled HTML from http://www.skysports.com/football/transfer-news
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/skysports/2018_01_27/base_urls/football_transfernews.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.telegraph.co.uk/premier-league/
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/telegraph/2018_01_27/base_urls/premierleague_.html
# Making directory /home/andreas/Desktop/Projects/Football/Data/01_HTML/telegraph/2018_01_27/base_urls/
# Successfully saved URL
#
# Finished reading 9 URLs, of which 0 failed

# %% [markdown]
# ## Block 4: Suburl extraction
#
# Getting the suburls from the HTML in block 3 and then scraping them

# %%
suburls.extract_urls(html_loc, organ_loc, date_today)
# Out:
# Now looking at sources from mirror
# Processing the HTML found in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/base_urls/sport_football_.html
# Have found 20 links from mirror
# Making directory /home/andreas/Desktop/Projects/Football/Data/00_Organisation/mirror/2018_01_27/
# Writing links file
# Finished writing to file
#
# Now looking at sources from bbc
# Processing the HTML found in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/bbc/2018_01_27/base_urls/sport_football_teams.html
# Have found 158 links from bbc
# Making directory /home/andreas/Desktop/Projects/Football/Data/00_Organisation/bbc/2018_01_27/
# Writing links file
# Finished writing to file
#
# Now looking at sources from dailymail
# Processing the HTML found in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/dailymail/2018_01_27/base_urls/sport_football_indexhtml.html
# Have found 24 links from dailymail
# Making directory /home/andreas/Desktop/Projects/Football/Data/00_Organisation/dailymail/2018_01_27/
# Writing links file
# Finished writing to file
#
# Now looking at sources from theguardian
# Processing the HTML found in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/base_urls/football_teams.html
# Have found 212 links from theguardian
# Making directory /home/andreas/Desktop/Projects/Football/Data/00_Organisation/theguardian/2018_01_27/
# Writing links file
# Finished writing to file
#
# Now looking at sources from telegraph
# Now looking at sources from skysports

# %%
suburl_errors = suburls.scrape_urls(organ_loc, html_loc, date_today, proxy_settings)
# Out:
# Successfully pulled HTML from http://www.mirror.co.uk/all-about/arsenal-fc
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/sublinks/allabout_arsenalfc.html
# Making directory /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/sublinks/
# Successfully saved URL
#
# Successfully pulled HTML from http://www.mirror.co.uk/all-about/afc-bournemouth
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/sublinks/allabout_afcbournemouth.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.mirror.co.uk/all-about/brighton-and-hove-albion-fc
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/sublinks/allabout_brightonandhovealbionfc.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.mirror.co.uk/all-about/burnley-fc
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/sublinks/allabout_burnleyfc.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.mirror.co.uk/all-about/chelsea-fc
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/sublinks/allabout_chelseafc.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.mirror.co.uk/all-about/crystal-palace-fc
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/sublinks/allabout_crystalpalacefc.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.mirror.co.uk/all-about/everton-fc
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/sublinks/allabout_evertonfc.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.mirror.co.uk/all-about/huddersfield-town-fc
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/sublinks/allabout_huddersfieldtownfc.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.mirror.co.uk/all-about/leicester-city-fc
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/sublinks/allabout_leicestercityfc.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.mirror.co.uk/all-about/liverpool-fc
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/sublinks/allabout_liverpoolfc.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.mirror.co.uk/all-about/manchester-city-fc
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/sublinks/allabout_manchestercityfc.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.mirror.co.uk/all-about/manchester-united-fc
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/sublinks/allabout_manchesterunitedfc.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.mirror.co.uk/all-about/newcastle-united-fc
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/sublinks/allabout_newcastleunitedfc.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.mirror.co.uk/all-about/southampton-fc
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/sublinks/allabout_southamptonfc.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.mirror.co.uk/all-about/stoke-city-fc
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/sublinks/allabout_stokecityfc.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.mirror.co.uk/all-about/swansea-city-fc
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/sublinks/allabout_swanseacityfc.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.mirror.co.uk/all-about/tottenham-hotspur-fc
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/sublinks/allabout_tottenhamhotspurfc.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.mirror.co.uk/all-about/watford-fc
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/sublinks/allabout_watfordfc.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.mirror.co.uk/all-about/west-bromwich-albion-fc
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/sublinks/allabout_westbromwichalbionfc.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.mirror.co.uk/all-about/west-ham-united-fc
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/sublinks/allabout_westhamunitedfc.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.bbc.co.uk/sport/football/teams/afc-bournemouth
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/bbc/2018_01_27/sublinks/sport_football_teams_afcbournemouth.html
# Making directory /home/andreas/Desktop/Projects/Football/Data/01_HTML/bbc/2018_01_27/sublinks/
# Successfully saved URL
#
# Successfully pulled HTML from http://www.bbc.co.uk/sport/football/teams/arsenal
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/bbc/2018_01_27/sublinks/sport_football_teams_arsenal.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.bbc.co.uk/sport/football/teams/brighton-and-hove-albion
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/bbc/2018_01_27/sublinks/sport_football_teams_brightonandhovealbion.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.bbc.co.uk/sport/football/teams/burnley
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/bbc/2018_01_27/sublinks/sport_football_teams_burnley.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.bbc.co.uk/sport/football/teams/chelsea
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/bbc/2018_01_27/sublinks/sport_football_teams_chelsea.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.bbc.co.uk/sport/football/teams/crystal-palace
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/bbc/2018_01_27/sublinks/sport_football_teams_crystalpalace.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.bbc.co.uk/sport/football/teams/everton
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/bbc/2018_01_27/sublinks/sport_football_teams_everton.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.bbc.co.uk/sport/football/teams/huddersfield-town
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/bbc/2018_01_27/sublinks/sport_football_teams_huddersfieldtown.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.bbc.co.uk/sport/football/teams/leicester-city
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/bbc/2018_01_27/sublinks/sport_football_teams_leicestercity.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.bbc.co.uk/sport/football/teams/liverpool
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/bbc/2018_01_27/sublinks/sport_football_teams_liverpool.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.bbc.co.uk/sport/football/teams/manchester-city
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/bbc/2018_01_27/sublinks/sport_football_teams_manchestercity.html
# Successfully saved URL
#
# Successfully pulled HTML from http://www.bbc.co.uk/sport/football/teams/manchester-united
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/bbc/2018_01_27/sublinks/sport_football_teams
html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/forest-green-rovers
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_forestgreenrovers.html
# Successfully saved URL
# Successfully pulled HTML from https://www.theguardian.com/football/grimsby
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_grimsby.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/lincoln
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_lincoln.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/lutontown
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_lutontown.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/mansfield
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_mansfield.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/morecambe
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_morecambe.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/newport-county
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_newportcounty.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/nottscounty
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_nottscounty.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/portvale
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_portvale.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/stevenage
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_stevenage.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/swindon
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_swindon.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/wycombe
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_wycombe.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/yeoviltown
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_yeoviltown.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/brechin
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_brechin.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/dumbarton
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_dumbarton.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/dundeeunited
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_dundeeunited.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/dunfermline
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_dunfermline.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/falkirk
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_falkirk.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/morton
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_morton.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/invernesscaledonianthistle
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_invernesscaledonianthistle.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/livingston
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_livingston.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/queenofthesouth
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_queenofthesouth.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/stmirren
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_stmirren.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/airdrie
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_airdrie.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/albion-rovers
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_albionrovers.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/alloa
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_alloa.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/arbroath
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_arbroath.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/ayr
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_ayr.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/eastfife
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_eastfife.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/forfar
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_forfar.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/queenspark
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_queenspark.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/raith
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_raith.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/stranraer
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_stranraer.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/annan-athletic
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_annanathletic.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/berwick
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_berwick.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/clyde
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_clyde.html
# Successfully saved URL
# Successfully pulled HTML from https://www.theguardian.com/football/cowdenbeath
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_cowdenbeath.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/edinburgh-city
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_edinburghcity.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/elgin
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_elgin.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/montrose
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_montrose.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/peterhead
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_peterhead.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/stenhousemuir
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_stenhousemuir.html
# Successfully saved URL
#
# Successfully pulled HTML from https://www.theguardian.com/football/stirling
# Saving HTML from URL in
# /home/andreas/Desktop/Projects/Football/Data/01_HTML/theguardian/2018_01_27/sublinks/football_stirling.html
# Successfully saved URL
#
# Finished reading 414 URLs, of which 0 failed

# %% [markdown]
# ## Block 5: Headline extraction
#
# Getting the headlines from all the HTML pages that we have looked at

# %%
headlines.process_html(html_loc, story_loc, date_today)
# Out:
# Making directory /home/andreas/Desktop/Projects/Football/Data/02_Stories/mirror/2018_01_27/
# Getting content from /home/andreas/Desktop/Projects/Football/Data/01_HTML/mirror/2018_01_27/base_urls/sport_football_.html
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-23cf12b6c48c> in <module>()
# ----> 1 headlines.process_html(html_loc, story_loc, date_today)
#
# ~/Desktop/Projects/Football/Scripts/football_functions/processes/information_extraction/headlines.py in process_html(html_loc, story_loc, date_today)
#      91             for html_page in os.listdir(domain_loc + link_type):
#      92                 html_loc = domain_loc + link_type + '/' + html_page
# ---> 93                 articles_info = extract_headlines(html_loc, story_loc, date_today, domain)
#
# ~/Desktop/Projects/Football/Scripts/football_functions/processes/information_extraction/headlines.py in extract_headlines(html_loc, story_loc, date_today, domain)
#      44
#      45     elif domain == 'mirror':
# ---> 46         articles_info = mirror.extract_mirror(html_content)
#      47
#      48     elif domain == 'skysports':
#
# AttributeError: module 'football_functions.source_specific.mirror' has no attribute 'extract_mirror'

# %% [markdown]
# ## Block 6: Story extraction
#
# Getting the HTML from the headline links that we found in block 5 - then getting the text *COMING SOON*

# %%
story_errors = stories.process_articles(story_loc, html_loc, date_today, proxy_settings)
