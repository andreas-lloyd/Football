# %% [markdown]
# Idea of script is is to loop over the data we have stored, bring it into a single DF, and then save it, so that we can CP easily and start working on stuff
#
# I guess this will also be useful long term as part of a sort of "utils" when we need to retrain or something

# %%
import pandas as pd
import json
from pathlib import Path

# %%
def loop_csv(stories_loc):
    json_files = stories_loc.glob('*/*/*/*/*.json')
    for json_file in json_files:
# Out:
#   File "<ipython-input-2-2361ea810092>", line 7
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
test_path = Path('/home/andreas/Desktop/Projects/Football/Data/Stories')

# %%
list(test_path.glob('*/*/*/*/*.json'))
# Out:
# [PosixPath('/home/andreas/Desktop/Projects/Football/Data/Stories/bbc/2018/11/11/sport_football_45847415.json'),
#  PosixPath('/home/andreas/Desktop/Projects/Football/Data/Stories/bbc/2018/11/11/sport_football_46046671.json'),
#  PosixPath('/home/andreas/Desktop/Projects/Football/Data/Stories/bbc/2018/11/11/sport_football_46013922.json'),
#  PosixPath('/home/andreas/Desktop/Projects/Football/Data/Stories/bbc/2018/11/11/sport_football_46023057.json'),
#  PosixPath('/home/andreas/Desktop/Projects/Football/Data/Stories/bbc/2018/11/11/sport_football_46156477.json'),
#  PosixPath('/home/andreas/Desktop/Projects/Football/Data/Stories/bbc/2018/11/11/sport_football_45847417.json'),
#  PosixPath('/home/andreas/Desktop/Projects/Football/Data/Stories/bbc/2018/11/11/sport_football_46044105.json'),
#  PosixPath('/home/andreas/Desktop/Projects/Football/Data/Stories/bbc/2018/11/11/sport_football_45689302.json'),
# ...
