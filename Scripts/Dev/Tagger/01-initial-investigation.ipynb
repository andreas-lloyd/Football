# %% [markdown]
# # First look
# The idea here should be to load in the data, have a quick look, and develop some of the initial processing steps to purely clean up the data, not necessarily get it in the state for the final modelling step to tag.
#
# I think it would be good to move all ready code into the "library" so that we can just pull it from there. Should aim to make it as light as possible, because we should be saving, in a database, step by step what we do
#
# Another aspect would be to find errors
#
# We can leave everything we find in the next block

# %% [markdown]
# ## Findings
#
# ...

# %%
from pathlib import Path
import pandas as pd
from basic_analysis import cloud_n_count
import re
from collections import Counter

data_loc = Path('/home/andreas/Desktop/Projects/Football/Data/Saved_stories')
save_loc = Path('/home/andreas/Dropbox/Projects/Football/Scripts/Dev/Tagger/data')

pd.set_option('max_colwidth', 1000)
pd.set_option('display.max_rows', 500)

# %%
stories = pd.read_csv(data_loc / 'stories.csv')

# %%
stories.shape
# Out:
# (19991, 10)

# %%
stories.head()
# Out:
#           article_date                                      article_image                                       article_link article_summary                                      article_title story_author story_date                                     story_keywords                                         story_text                                      story_twitter
# 0  2019-03-30T10:30:00                  Son Hueng-min gives the thumbs up  http://www.telegraph.co.uk/football/2019/03/30...             NaN  Son Hueng-min: Tottenham players must now live...          NaN        NaN  ['Tottenham Hotspur FC,Son Heung-min,Sport,Foo...  \nFollow your club now for first access to all...  They have one of the finest training grounds, ...
# 1  2019-03-30T05:07:14  Burnley's Dwight McNeil celebrates scoring his...  http://www.telegraph.co.uk/football/2019/03/30...             NaN  Burnley boost survival hopes on landmark day f...          NaN        NaN  ['Wolverhampton Wanderers FC,Sport,Football,Pr...  \nFollow your club now for first access to all...  Dwight McNeil capped the sort of week that sho...
# 2  2019-03-30T05:06:08      Wes Morgan scores with an improbable backheel  http://www.telegraph.co.uk/football/2019/03/30...             NaN  Wes Morgan marks Leicester return with backhee...          NaN        NaN  ['Sport,Leicester City FC,Football,Premier Lea...  \nFollow your club now for first access to all...  The &pound;9m compensation fee Leicester paid ...
# 3  2019-03-31T08:00:00                    Pochettino, Torreira and Hazard  http://www.telegraph.co.uk/football/2019/03/31...             NaN  What missing out on the Premier League top fou...          NaN        NaN  ['Tottenham Hotspur FC,Sport,Football,Standard...  \nFollow your club now for first access to all...  With eight games left to go for Tottenham, Ars...
# 4  2019-03-30T10:30:00                   James Forrest in action at Ibrox  http://www.telegraph.co.uk/football/2019/03/30...             NaN  James Forrest reveals hurt of defeat by Ranger...          NaN        NaN  ['Sport,Football,Standard,Steven Gerrard,Brend...  It was to be the last Old Firm collision of Br...  It was to be the last Old Firm collision of Br...

# %%
print(stories.shape)
print(stories.drop_duplicates().shape)
print(stories.article_link.nunique())
print(stories.article_title.nunique())

condition = stories.article_link.str.contains('fake_link').fillna(False)
print(stories[~ condition].article_link.nunique())
# Out:
# (19991, 10)
# (19060, 10)
# 17913
# 18465
# 17864

# %% [markdown]
# Interesting that we have some duplicates - do some value counts

# %%
stories[~ condition].article_link.value_counts().head()
# Out:
# https://www.dailymail.co.uk/sport/football/article-6559019/Father-Cardiff-City-youth-player-slams-toxic-Craig-Bellamy.html    1
# https://www.theguardian.com/football/2018/nov/15/alexis-sanchez-manchester-united-10percent-wage-bill-rise                    1
# http://www.bbc.com/sport/football/47064928                                                                                    1
# https://www.theguardian.com/football/2016/mar/19/inverness-hearts-st-johnstone-scottish-premiership                           1
# https://www.dailymail.co.uk/sport/football/article-6868569/Solskjaer-bold-choice-works-United-worry-results-money.html        1
# Name: article_link, dtype: int64

# %%
stories['num_duplicates'] = stories.groupby('article_title')['article_link'].transform('count')

# %%
bad_titles = [
    'Who was your man of the match', 
    "The Dozen: the weekend",
    'Who is in Garth'
]
regex = '(?:' + '|'.join(bad_titles) + ')'

has_bad_title = stories.article_title.str.contains(regex).fillna(False)
has_empty = (stories.num_duplicates > 1) & (stories.story_text.isna())

condition = (~ has_bad_title) & (~ has_empty) & (stories.article_title.notna())

# %%
# Pretty OK with what is here
reduced_stories = stories[condition].reset_index(drop = True)

# %% [markdown]
# Now need to do some things like cleaning up basic stuff that is included and don't want - this will typically be basic text that is repeated a lot. This would typically be in the text, not sure what would find in the title or whatever.
#
# * Maybe should take the texts and find the most common bigrams / trigrams
# * Then eliminate what looks bad

# %%
_ = cloud_n_count(reduced_stories.article_title.tolist(), most_common = 30, n_gram = 2, most_common_ng = 30)
_ = cloud_n_count(reduced_stories.article_title.tolist(), most_common = 0, n_gram = 3, most_common_ng = 30)
_ = cloud_n_count(reduced_stories.article_title.tolist(), most_common = 0, n_gram = 6, most_common_ng = 30)
# Out:
# The 30 most common words are the following:
# [("'", 9375), ('to', 7048), ('-', 6609), ('the', 4385), ('s', 4152), ('in', 3542), ('for', 3224), ('and', 2954), ('of', 2952), ('as', 2904), (':', 2685), ('a', 2282), (',', 2262), ('United', 2063), ('on', 2058), ('at', 2034), ('Manchester', 2031), ('with', 1821), ('’', 1812), ('League', 1792), ('City', 1762), ('after', 1739), ('is', 1518), ("':", 1410), ('Liverpool', 1293), ('1', 1270), ('Chelsea', 1231), ('he', 1224), ('his', 1092), ('Premier', 1064)]
#
# The 30 most common ngrams are the following:
# [(("'", 's'), 3002), (('Manchester', 'United'), 1176), (('’', 's'), 1137), (('Premier', 'League'), 1061), (('Manchester', 'City'), 825), (('-', '0'), 624), (('-', '1'), 600), (('in', 'the'), 580), (('1', '-'), 565), (('of', 'the'), 514), (('West', 'Ham'), 445), (('0', '-'), 424), (('2', '-'), 423), (('FA', 'Cup'), 422), (("'", 't'), 395), (('-', '2'), 394), (("'", 'I'), 372), (('Real', 'Madrid'), 368), (('Ole', 'Gunnar'), 359), (('Champions', 'League'), 339), (('Gunnar', 'Solskjaer'), 322), (('as', 'it'), 315), (('it', 'happened'), 312), (('Crystal', 'Palace'), 288), (('–', 'as'), 285), (('as', 'he'), 275), (('to', 'be'), 259), (('Maurizio', 'Sarri'), 256), (('3', '-'), 256), (('Pep', 'Guardiola'), 242)]
# The 0 most common words are the following:
# []
#
# The 30 most common ngrams are the following:
# [(('Ole', 'Gunnar', 'Solskjaer'), 322), (('as', 'it', 'happened'), 307), (('–', 'as', 'it'), 284), (('the', 'Premier', 'League'), 219), ((':', 'match', 'preview'), 195), (('1', '-', '1'), 183), (('1', '-', '0'), 160), (('2', '-', '0'), 154), (('2', '-', '1'), 144), (('1', '-', '2'), 131), (('0', '-', '1'), 130), (('Hudson', '-', 'Odoi'), 126), (('0', '-', '0'), 120), (('Manchester', 'United', "'"), 118), (('Liverpool', "'", 's'), 117), ((':', 'Premier', 'League'), 114), (('League', '–', 'as'), 114), (('United', "'", 's'), 112), (("'", 's', 'side'), 110), (('of', 'the', 'season'), 108), (('don', "'", 't'), 106), (('Premier', 'League', '–'), 101), (('It', "'", 's'), 100), (('I', "'", 'm'), 96), (('0', '-', '2'), 94), (('3', '-', '0'), 92), (('he', "'", 's'), 89), (('3', '-', '1'), 86), (('Callum', 'Hudson', '-'), 85), (('it', "'", 's'), 85)]
# The 0 most common words are the following:
# []
#
# The 30 most common ngrams are the following:
# [(('what', 'TV', 'channel', 'is', 'it', 'on'), 82), ((',', 'what', 'TV', 'channel', 'is', 'it'), 81), (('TV', 'channel', 'is', 'it', 'on', 'and'), 81), ((':', 'Premier', 'League', '–', 'as', 'it'), 79), (('Premier', 'League', '–', 'as', 'it', 'happened'), 79), (('channel', 'is', 'it', 'on', 'and', 'what'), 76), (('is', 'it', 'on', 'and', 'what', 'is'), 72), (('it', 'on', 'and', 'what', 'is', 'our'), 72), (('on', 'and', 'what', 'is', 'our', 'prediction'), 72), (('and', 'what', 'is', 'our', 'prediction', '?'), 72), ((':', 'What', 'time', 'is', 'kick', '-'), 68), (('What', 'time', 'is', 'kick', '-', 'off'), 68), (('time', 'is', 'kick', '-', 'off', ','), 48), (('is', 'kick', '-', 'off', ',', 'what'), 48), (('kick', '-', 'off', ',', 'what', 'TV'), 48), (('-', 'off', ',', 'what', 'TV', 'channel'), 48), (('off', ',', 'what', 'TV', 'channel', 'is'), 48), (('2018', '-', '19', ':', 'What', 'time'), 38), (('-', '19', ':', 'What', 'time', 'is'), 38), ((',', 'Premier', 'League', '2018', '-', '19'), 37), (('Premier', 'League', '2018', '-', '19', ':'), 37), (('League', '2018', '-', '19', ':', 'What'), 37), (('19', ':', 'What', 'time', 'is', 'kick'), 37), ((',', '000', '-', 'a', '-', 'week'), 29), ((':', 'La', 'Liga', '–', 'as', 'it'), 27), (('La', 'Liga', '–', 'as', 'it', 'happened'), 27), ((',', 'Premier', 'League', ':', 'What', 'time'), 25), (('Premier', 'League', ':', 'What', 'time', 'is'), 25), ((':', '10', 'talking', 'points', 'from', 'the'), 24), (('League', ':', 'What', 'time', 'is', 'kick'), 23)]

# %%
c = reduced_stories.article_summary.notna()
_ = cloud_n_count(reduced_stories.loc[c, 'article_summary'].tolist(), most_common = 30, n_gram = 2, most_common_ng = 30)
_ = cloud_n_count(reduced_stories.loc[c, 'article_summary'].tolist(), most_common = 0, n_gram = 3, most_common_ng = 30)
_ = cloud_n_count(reduced_stories.loc[c, 'article_summary'].tolist(), most_common = 0, n_gram = 6, most_common_ng = 30)
# Out:
# The 30 most common words are the following:
# [('the', 13388), ('.', 11575), ('to', 8457), ('a', 7003), ('-', 6966), ('of', 5834), ('in', 5368), (',', 5299), ('s', 5094), ("'", 5077), ('and', 4946), ('at', 3374), ('on', 3260), ('for', 3133), ('his', 3051), ('League', 2735), ('with', 2650), ('as', 2423), ('has', 2275), ('is', 2229), ('their', 2067), ('from', 1882), ('after', 1871), ('he', 1717), ('United', 1695), ('’', 1653), ('The', 1621), ('Manchester', 1609), ('by', 1535), ('City', 1503)]
#
# The 30 most common ngrams are the following:
# [(("'", 's'), 3780), (('in', 'the'), 1800), (('of', 'the'), 1747), (('’', 's'), 1297), (('Premier', 'League'), 1235), (('Manchester', 'United'), 919), (('at', 'the'), 853), (('-', '0'), 760), (('for', 'the'), 716), (('to', 'the'), 701), (('Manchester', 'City'), 647), (('the', 'club'), 630), (('the', 'Premier'), 598), (('with', 'a'), 561), (('game', 'between'), 558), (('coverage', 'of'), 556), (('-', '1'), 546), (('-', 'year'), 529), (('2', '-'), 483), (('the', 'season'), 479), (('FA', 'Cup'), 439), (('Saturday', "'"), 423), (('in', 'a'), 415), (('on', 'the'), 398), (('followed', 'by'), 394), (('has', 'been'), 391), (('.', 'The'), 385), (('live', 'coverage'), 383), (('by', 'live'), 373), (('League', 'game'), 369)]
# The 0 most common words are the following:
# []
#
# The 30 most common ngrams are the following:
# [(('the', 'Premier', 'League'), 597), (('Saturday', "'", 's'), 423), (('of', 'the', 'season'), 419), (('live', 'coverage', 'of'), 375), (('followed', 'by', 'live'), 373), (('by', 'live', 'coverage'), 373), (('-', 'year', '-'), 356), (('year', '-', 'old'), 351), (('of', 'Saturday', "'"), 332), (('Preview', 'followed', 'by'), 332), (('League', 'game', 'between'), 332), (('coverage', 'of', 'Saturday'), 308), (('the', 'end', 'of'), 271), (('Ole', 'Gunnar', 'Solskjaer'), 255), (('end', 'of', 'the'), 239), (('in', 'the', 'Premier'), 231), (('s', 'Premier', 'League'), 223), (('2', '-', '0'), 222), (("'", 's', 'Premier'), 219), (('the', 'season', '.'), 212), (('-', '0', 'win'), 203), (('1', '-', '0'), 200), (('2', '-', '1'), 198), (('Premier', 'League', 'game'), 195), (('the', 'top', 'of'), 192), (('the', 'FA', 'Cup'), 182), (('Live', 'coverage', 'of'), 179), (('top', 'of', 'the'), 170), (('a', '2', '-'), 168), (('until', 'the', 'end'), 160)]
# The 0 most common words are the following:
# []
#
# The 30 most common ngrams are the following:
# [(('Preview', 'followed', 'by', 'live', 'coverage', 'of'), 332), (('followed', 'by', 'live', 'coverage', 'of', 'Saturday'), 174), (('by', 'live', 'coverage', 'of', 'Saturday', "'"), 174), (('live', 'coverage', 'of', 'Saturday', "'", 's'), 174), (("'", 's', 'Premier', 'League', 'game', 'between'), 167), (('until', 'the', 'end', 'of', 'the', 'season'), 146), (("'", 's', 'National', 'League', 'game', 'between'), 142), (('Live', 'coverage', 'of', 'Saturday', "'", 's'), 134), (('the', 'end', 'of', 'the', 'season', '.'), 133), (('Saturday', "'", 's', 'National', 'League', 'game'), 113), (('coverage', 'of', 'Saturday', "'", 's', 'National'), 111), (('of', 'Saturday', "'", 's', 'National', 'League'), 111), (('Saturday', "'", 's', 'Premier', 'League', 'game'), 95), (('coverage', 'of', 'Saturday', "'", 's', 'Premier'), 94), (('of', 'Saturday', "'", 's', 'Premier', 'League'), 94), (('followed', 'by', 'live', 'coverage', 'of', 'Sunday'), 57), (('by', 'live', 'coverage', 'of', 'Sunday', "'"), 57), (('live', 'coverage', 'of', 'Sunday', "'", 's'), 57), (('-', 'and', '-', 'a', '-', 'half'), 56), (('for', 'the', 'rest', 'of', 'the', 'season'), 52), (('on', 'loan', 'until', 'the', 'end', 'of'), 50), (('loan', 'until', 'the', 'end', 'of', 'the'), 49), ((',', 'Sky', 'Sports', 'News', 'understands', '.'), 49), (('in', 'the', 'Premier', 'League', '-', 'watch'), 45), (('followed', 'by', 'live', 'coverage', 'of', 'Tuesday'), 44), (('by', 'live', 'coverage', 'of', 'Tuesday', "'"), 44), (('live', 'coverage', 'of', 'Tuesday', "'", 's'), 44), (('followed', 'by', 'live', 'coverage', 'of', 'Wednesday'), 43), (('by', 'live', 'coverage', 'of', 'Wednesday', "'"), 43), (('live', 'coverage', 'of', 'Wednesday', "'", 's'), 43)]

# %%
c = reduced_stories.story_text.notna()
_ = cloud_n_count(reduced_stories.loc[c, 'story_text'].tolist(), most_common = 30, n_gram = 2, most_common_ng = 30)
_ = cloud_n_count(reduced_stories.loc[c, 'story_text'].tolist(), most_common = 0, n_gram = 3, most_common_ng = 30)
_ = cloud_n_count(reduced_stories.loc[c, 'story_text'].tolist(), most_common = 0, n_gram = 6, most_common_ng = 30)
# Out:
# The 30 most common words are the following:
# [('.', 582050), ('the', 555483), (',', 416804), ('to', 294252), ('a', 258524), ('and', 224110), ('in', 212158), ('of', 187502), ('-', 180355), ('s', 136945), ("'", 136155), ('for', 109788), ('on', 107703), ('is', 99932), ('with', 96892), ('’', 88813), ('at', 85334), ('was', 82518), ('his', 79726), ('that', 74857), ('from', 73598), ('he', 72424), ('it', 66329), ('have', 64300), ('I', 64093), ('(', 62959), ('by', 57536), ('but', 56247), ('The', 55821), ('as', 55469)]
#
# The 30 most common ngrams are the following:
# [(('in', 'the'), 79531), (("'", 's'), 77432), (('’', 's'), 59247), (('of', 'the'), 58255), (('.', 'The'), 41235), (('to', 'the'), 26117), (('on', 'the'), 24290), ((',', 'but'), 23471), (('at', 'the'), 23408), (('for', 'the'), 22086), ((',', 'and'), 21049), (('from', 'the'), 18931), (('.', 'He'), 17215), ((',', 'who'), 17083), (('to', 'be'), 16666), (('.', 'It'), 16413), (('Premier', 'League'), 16392), ((',', 'the'), 16159), (('the', 'club'), 15246), (("'", 't'), 14473), (('with', 'a'), 14181), (('the', 'box'), 13991), (('a', 'free'), 13821), (('.', '“'), 13199), (('free', 'kick'), 12942), (('in', 'a'), 12933), (('-', '0'), 12631), (('wins', 'a'), 12371), ((',', 'with'), 12365), (('for', 'a'), 12261)]
# The 0 most common words are the following:
# []
#
# The 30 most common ngrams are the following:
# [(('a', 'free', 'kick'), 12329), (('wins', 'a', 'free'), 12188), ((')', 'wins', 'a'), 12130), (('Share', 'this', 'with'), 11644), (('.', 'Foul', 'by'), 11121), (('footed', 'shot', 'from'), 10675), (('kick', 'in', 'the'), 9078), (('free', 'kick', 'in'), 8999), (('the', 'box', 'is'), 8791), (('-', 'year', '-'), 8726), (('year', '-', 'old'), 8682), (('the', 'Premier', 'League'), 8331), (('this', 'with', '.'), 8328), (('right', 'footed', 'shot'), 7582), ((')', 'right', 'footed'), 7195), (('of', 'the', 'box'), 6983), (('centre', 'of', 'the'), 6464), (('of', 'the', 'season'), 6303), (('the', 'centre', 'of'), 6072), (('.', 'Conceded', 'by'), 5914), (('.', 'Substitution', ','), 5863), (('outside', 'the', 'box'), 5240), (('from', 'outside', 'the'), 5233), (('in', 'the', 'defensive'), 5211), (('half', '.', 'Foul'), 5179), (('the', 'defensive', 'half'), 5175), (('defensive', 'half', '.'), 5170), (('shot', 'from', 'outside'), 5078), (('.', 'Corner', ','), 5078), (('it', "'", 's'), 5047)]
# The 0 most common words are the following:
# []
#
# The 30 most common ngrams are the following:
# [(('wins', 'a', 'free', 'kick', 'in', 'the'), 8969), ((')', 'wins', 'a', 'free', 'kick', 'in'), 8967), (('a', 'free', 'kick', 'in', 'the', 'defensive'), 5174), (('free', 'kick', 'in', 'the', 'defensive', 'half'), 5174), (('kick', 'in', 'the', 'defensive', 'half', '.'), 5170), (('footed', 'shot', 'from', 'outside', 'the', 'box'), 5047), (('from', 'the', 'centre', 'of', 'the', 'box'), 4269), (('shot', 'from', 'outside', 'the', 'box', 'is'), 4176), (('a', 'free', 'kick', 'in', 'the', 'attacking'), 3796), (('free', 'kick', 'in', 'the', 'attacking', 'half'), 3795), (('kick', 'in', 'the', 'attacking', 'half', '.'), 3791), (('right', 'footed', 'shot', 'from', 'outside', 'the'), 3511), ((')', 'right', 'footed', 'shot', 'from', 'outside'), 3442), ((')', 'is', 'shown', 'the', 'yellow', 'card'), 3347), ((')', 'right', 'footed', 'shot', 'from', 'the'), 3262), (('wins', 'a', 'free', 'kick', 'on', 'the'), 3165), ((')', 'wins', 'a', 'free', 'kick', 'on'), 3163), (('the', 'centre', 'of', 'the', 'box', 'is'), 2995), (('in', 'the', 'defensive', 'half', '.', 'Foul'), 2968), (('the', 'defensive', 'half', '.', 'Foul', 'by'), 2968), (('the', 'box', 'is', 'saved', 'in', 'the'), 2822), (('Get', 'latest', 'scores', 'and', 'headlines', 'sent'), 2802), (('latest', 'scores', 'and', 'headlines', 'sent', 'straight'), 2802), (('scores', 'and', 'headlines', 'sent', 'straight', 'to'), 2802), (('and', 'headlines', 'sent', 'straight', 'to', 'your'), 2802), (('headlines', 'sent', 'straight', 'to', 'your', 'phone'), 2802), (('sent', 'straight', 'to', 'your', 'phone', ','), 2802), (('straight', 'to', 'your', 'phone', ',', 'sign'), 2802), (('to', 'your', 'phone', ',', 'sign', '-'), 2802), (('your', 'phone', ',', 'sign', '-', 'up'), 2802)]

# %% [markdown]
# Can see examples of generic stuff that don't really want - but mostly have
#
# * Titles and summaries that are not particularly interesting
# * Texts with generic filler stuff, that can get rid of
#
# I think maybe better off splitting into sentences to remove
#
# Use `Counter` method to find common sentences that are shitty and we replace
#
# Note that I guess we just replace them here to make the visual analysis easier - because it really isn't that important for the sake of analysis to remove this info. If we wanted to remove it, we would have to develop some automatic system
# - I guess some TFIDF style approach on sentences would be quite good
# - Maybe should just remove all sentences that are above a certain count
#
# Maybe should leave this for now until we want to do story summaries, as by that time we will probably have a very different looking set of texts

# %%
c = reduced_stories.story_text.notna()
story_texts = reduced_stories.loc[c, 'story_text'].tolist()
sentences = [sentence.strip() for story in story_texts for sentence in re.split('(?:\\n|[\.?!])', story) if sentence != '']
sentence_count = Counter(sentences)

# %%
sentence_count.most_common(5)
# Out:
# [('Share this with', 9408),
#  ('', 7385),
#  ('Attempt missed', 4967),
#  ('4', 4612),
#  ('Attempt saved', 3187)]

# %% [markdown]
# Maybe the thing to do is to move directly to use spacy to try and tag stuff and see what we have to play with - correct this, build a model, then test that model on the texts etc.
#
# https://spacy.io/usage/linguistic-features#named-entities
#
# Note that there may be some odd things that we have to remove before extracting entities, like punctuation
#
# For now - just go through and pull the entities and start iterating to make the job easier.
# The task should be to move through and correct, so that we can correct

# %%
import spacy
disable = ['parser', 'textcat']
nlp = spacy.load('en_core_web_lg', disable = disable)

def is_stop(token):
    try:
        return token.text.lower() in nlp.Defaults.stop_words
    except:
        return False

# %%
i = 0
title_entities = []
text_list = reduced_stories.article_title.tolist()
unwanted_ents = ['DATE', 'ORDINAL', 'CARDINAL', 'TIME']

# Remove all bad
regex_replace = '[^A-zÀ-ÿ0-9\- ]'

# Remove all non-alpha from start and end
regex_strip_start = '^[^A-zÀ-ÿ0-9]*'
regex_strip_end = '[^A-zÀ-ÿ0-9]*$'

fix_ent = lambda ent: re.sub(regex_strip_end, '', re.sub(regex_strip_start, '', re.sub(regex_replace, '', ent.replace("'s", ''))))

for doc in nlp.pipe(text_list, batch_size = 10000, n_threads = 4):
    if i % 1000 == 0:
        print('Done with {} of {} docs'.format(i, len(text_list)))
    
    # Not particularly interested in location as we want to count and normalise
    treated_text = [(fix_ent(ent.text), ent.label_) for ent in doc.ents if ent.label_ not in unwanted_ents]
    title_entities.append(treated_text)
    i += 1
# Out:
# Done with 0 of 18524 docs
# Done with 1000 of 18524 docs
# Done with 2000 of 18524 docs
# Done with 3000 of 18524 docs
# Done with 4000 of 18524 docs
# Done with 5000 of 18524 docs
# Done with 6000 of 18524 docs
# Done with 7000 of 18524 docs
# Done with 8000 of 18524 docs
# Done with 9000 of 18524 docs
# Done with 10000 of 18524 docs
# Done with 11000 of 18524 docs
# Done with 12000 of 18524 docs
# Done with 13000 of 18524 docs
# Done with 14000 of 18524 docs
# Done with 15000 of 18524 docs
# Done with 16000 of 18524 docs
# Done with 17000 of 18524 docs
# Done with 18000 of 18524 docs

# %%
entity_results = pd.DataFrame({
    'headline' : text_list,
    'entities' : title_entities
})

# %%
entity_results.to_excel(save_loc / 'headline_entities_v0.xlsx', index = False)

# %%
title_entities
# Out:
# [[('Son Hueng-min', 'PERSON'), ('Tottenham', 'PERSON'), ('Spurs', 'ORG')],
#  [('Burnley', 'PERSON'), ('Sean Dyche', 'PERSON')],
#  [('Wes Morgan', 'PERSON'),
#   ('Leicester', 'GPE'),
#   ('Brendan Rodgers', 'PERSON')],
#  [('the Premier League', 'ORG'), ('London', 'GPE')],
#  [('James Forrest', 'PERSON'), ('Rangers', 'ORG'), ('Celtic', 'NORP')],
#  [('Watford', 'ORG'), ('Ole Gunnar Solskjaer', 'PERSON')],
#  [('Paul Gascoigne', 'PERSON'),
#   ('Spurs', 'ORG'),
#   ('Tottenham', 'GPE'),
#   ('Inter Milan', 'ORG')],
#  [('Manchester City', 'GPE'), ('Fulham', 'GPE'), ('Premier League', 'ORG')],
#  [('Pierre-Emile Hojbjerg', 'PERSON'),
#   ('Southampton', 'GPE'),
#   ('Brighton', 'GPE')],
#  [('Phil Neville', 'PERSON'),
#   ('Lucy Bronze', 'PERSON'),
#   ('England', 'GPE'),
#   ('World Cup', 'EVENT')],
#  [('Everton', 'ORG'), ('Michael Keane', 'PERSON')],
#  [('Michy Batshuayi', 'PERSON'),
#   ('Crystal Palace', 'FAC'),
#   ('Burnley', 'PERSON')],
#  [('Beyonce', 'ORG'),
#   ('Rowling', 'PERSON'),
#   ('Mother Theresa', 'PERSON'),
#   ('England', 'GPE'),
#   ('USA Women', 'ORG'),
#   ('SheBelieves Cup', 'EVENT')],
#  [('David Beckham', 'PERSON'), ('LA Galaxy', 'ORG')],
#  [('Riyad Mahrez', 'PERSON'),
#   ('Manchester City', 'GPE'),
#   ('Bournemouth', 'GPE')],
#  [('Unai Emery', 'PERSON'),
#   ('Wembley', 'GPE'),
#   ('Shkodran Mustafi', 'PERSON')],
#  [('Florin Andone', 'PERSON'), ('Brighton', 'GPE'), ('Huddersfield', 'ORG')],
#  [('Everton vs Liverpool', 'ORG'), ('Premier League', 'ORG')],
#  [('England', 'GPE'), ('USA', 'GPE'), ('SheBelieves', 'NORP')],
#  [('Cardiff City', 'GPE')],
#  [],
#  [('Peter Beardsley', 'PERSON'), ('FA', 'ORG'), ('Newcastle', 'GPE')],
#  [('Raheem Sterling', 'PERSON'),
#   ('England', 'GPE'),
#   ('Czechs', 'NORP'),
#   ('Euro 2020', 'LAW')],
#  [('Mauricio Pochettino', 'PERSON'), ('Tottenham', 'GPE')],
#  [('England', 'GPE'), ('Manchester United', 'ORG')],
#  [('Premier League', 'ORG'),
#   ('Gary Verity', 'PERSON'),
#   ('Tour de Yorkshire', 'ORG')],
#  [('Chris Kirkland', 'PERSON'), ('Liverpool Women', 'ORG')],
#  [('Jadon Sancho', 'PERSON'),
#   ('England', 'GPE'),
#   ('Czech Republic', 'GPE'),
#   ('Marcus Rashford', 'PERSON')],
#  [('Birmingham City', 'GPE'), ('EFL', 'ORG')],
#  [('Declan', 'PERSON'), ('Rice', 'PERSON')],
#  [('Poland', 'GPE')],
#  [('PSG', 'ORG'), ('Champions League', 'ORG'), ('Chelsea Women', 'ORG')],
#  [('Marcus Rashford', 'PERSON'), ('Jose Mourinho', 'PERSON')],
#  [('VAR', 'ORG'), ('FA Cup', 'EVENT')],
#  [('Liverpool', 'GPE'),
#   ('Trent Alexander-Arnold', 'PERSON'),
#   ('England', 'GPE')],
#  [('Tottenham', 'PERSON')],
#  [('Marc Overmars', 'PERSON'), ('Ajax', 'ORG')],
#  [('James Milner', 'PERSON'),
#   ('Liverpool', 'GPE'),
#   ('Fulham', 'GPE'),
#   ('Premier League', 'ORG')],
#  [('Maurizio Sarri', 'PERSON'), ('Napoli', 'GPE'), ('Chelsea', 'PERSON')],
#  [('Glenn Murray', 'PERSON'),
#   ('Brighton', 'GPE'),
#   ('Crystal Palace', 'FAC'),
#   ('Millwall FA Cup', 'ORG')],
#  [('Tony Carr - the', 'PERSON'), ('English', 'NORP'), ('West Ham', 'LOC')],
#  [('Manchester City', 'GPE'), ('Barry Bennell', 'PERSON')],
#  [('Liverpool', 'GPE'), ('Chelsea', 'ORG'), ('Southampton', 'GPE')],
#  [('Salomon Rondon', 'ORG'),
#   ('Ayoze Perez', 'PERSON'),
#   ('Newcastle United', 'GPE')],
#  [('Ayoze Perez', 'PERSON'), ('Newcastle', 'GPE')],
#  [('Newcastle', 'GPE'), ('Matt Ritchie', 'PERSON'), ('Bournemouth', 'GPE')],
#  [('Lisa Robertson', 'PERSON'),
#   ('FA', 'ORG'),
#   ('Durham', 'GPE'),
#   ('Chelsea', 'PERSON')],
#  [('Jurgen Klopp', 'PERSON'),
#   ('Franz Beckenbauer', 'PERSON'),
#   ('Liverpool', 'GPE')],
#  [('Mahlon Romeo', 'PERSON'),
#   ('Millwall', 'NORP'),
#   ('FA Cup', 'EVENT'),
#   ('Brighton', 'GPE')],
#  [('Sheffield', 'GPE'), ('Leeds', 'GPE')],
#  [('Scotland', 'GPE'), ('Euro 2020', 'LAW')],
#  [('Everton', 'ORG'), ('Marco Silva', 'PERSON'), ('Chelsea', 'PERSON')],
#  [('Man Utd', 'PERSON')],
#  [('Wembley', 'GPE'), ('England', 'GPE'), ('Czech Republic', 'GPE')],
#  [('Raheem Sterling', 'PERSON'),
#   ('Harry Kane', 'PERSON'),
#   ('Jadon Sancho', 'PERSON')],
#  [('Willie McKay', 'PERSON'), ('Cardiff City', 'GPE')],
#  [('the FA Cup', 'EVENT'),
#   ('Wigan', 'PERSON'),
#   ('James McArthur', 'PERSON'),
#   ('Wembley', 'GPE')],
#  [('England', 'GPE'),
#   ('James Ward-Prowse', 'PERSON'),
#   ('Jordan Henderson', 'PERSON')],
#  [('Manchester United', 'ORG'), ('FA Cup', 'EVENT')],
#  [('Fulham', 'GPE'), ('Liverpool', 'GPE'), ('Premier League', 'ORG')],
#  [('Manchester United', 'GPE')],
#  [('Ole Gunnar Solskjaer', 'PERSON'),
#   ('Manchester United', 'ORG'),
#   ('Champions League', 'ORG'),
#   ('Barcelona', 'GPE')],
#  [('Ryan Giggs', 'PERSON'),
#   ('Ben Woodburn', 'PERSON'),
#   ('Euro 2020', 'LAW'),
#   ('Slovakia', 'GPE')],
#  [('Callum Hudson-Odoi', 'PERSON'),
#   ('Jadon Sancho', 'PERSON'),
#   ('England', 'GPE'),
#   ('U17s World Cup', 'ORG')],
#  [('England', 'GPE'), ('Callum Hudson-Odoi', 'PERSON')],
#  [('Paul Pogba', 'PERSON'),
#   ('Manchester United', 'ORG'),
#   ('Real Madrid', 'ORG')],
#  [('Manchester United', 'ORG'), ('Barcelona', 'ORG'), ('Uefa', 'ORG')],
#  [('Home Nations', 'ORG')],
#  [('Man Utd', 'PERSON'), ('Watford', 'ORG'), ('Premier League', 'ORG')],
#  [('Premier League', 'ORG')],
#  [('Manchester United', 'ORG'),
#   ('Far East', 'LOC'),
#   ('Shanghai', 'GPE'),
#   ('Tottenham', 'GPE')],
#  [('Tottenham', 'PERSON'), ('Liverpool', 'GPE'), ('Spurs', 'ORG')],
#  [('Manchester United', 'ORG'), ('Ole Gunnar Solskjaer', 'PERSON')],
#  [('Louis van Gaal', 'PERSON'),
#   ('Tottenham', 'PERSON'),
#   ('Manchester United', 'ORG')],
#  [('Gordon Taylor', 'PERSON'), ('PFA', 'ORG')],
#  [('Ole Gunnar Solskjaer', 'PERSON'), ('Manchester United', 'ORG')],
#  [('England under-21s', 'ORG'), ('Germany', 'GPE')],
#  [('Gareth Southgate', 'PERSON'), ('England', 'GPE'), ('Montenegro', 'GPE')],
#  [('Michael Gove', 'PERSON'), ('QPR', 'ORG')],
#  [('Raheem Sterling', 'PERSON'), ('English', 'NORP')],
#  [('Manchester United', 'ORG'), ('Ole Gunnar Solskjaer', 'ORG')],
#  [('James Maddison', 'PERSON'), ('England', 'GPE'), ('U21s', 'ORG')],
#  [('Wales', 'GPE'),
#   ('Daniel James', 'PERSON'),
#   ('Ryan Giggs', 'PERSON'),
#   ('Gareth Bale', 'PERSON')],
#  [('Premier League', 'ORG'), ('No Room for Racism', 'WORK_OF_ART')],
#  [('Uefa', 'ORG'), ('Montenegro', 'GPE'), ('England', 'GPE')],
#  [('England', 'GPE'),
#   ('Canada', 'GPE'),
#   ('Spain', 'GPE'),
#   ('World Cup', 'EVENT')],
#  [('Raheem Sterling', 'PERSON'), ('Montenegro', 'GPE')],
#  [('Sunderland', 'PERSON')],
#  [('Denis Suarez', 'PERSON'), ('Unai Emery', 'PERSON')],
#  [('Premier League', 'ORG')],
#  [('Cardiff City', 'GPE'), ('Chelsea', 'PERSON'), ('Premier League', 'ORG')],
#  [('Manchester United', 'ORG'), ('Watford', 'ORG'), ('Premier League', 'ORG')],
#  [],
#  [('Roberto Firmino', 'PERSON'), ('Liverpool', 'GPE')],
#  [('Montenegro', 'GPE'),
#   ('Callum Hudson-Odoi', 'PERSON'),
#   ('Chelsea', 'PERSON'),
#   ('Maurizio Sarri', 'PERSON')],
#  [('Ole Gunnar Solskjaer', 'PERSON'),
#   ('Paul Pogba', 'PERSON'),
#   ('Marcus Rashford', 'PERSON'),
#   ('Manchester United', 'ORG')],
#  [('Champions League', 'ORG')],
#  [('Jubilant Liverpool', 'ORG'),
#   ('Jurgen Klopp', 'PERSON'),
#   ('Bayern Munich', 'GPE')],
#  [('Bernardo Silva', 'PERSON'), ('Manchester City', 'GPE')],
#  [('Lionel Messi', 'PERSON'),
#   ('Lyon', 'GPE'),
#   ('Barcelona', 'GPE'),
#   ('Champions', 'EVENT')],
#  [('Leicester City', 'GPE'),
#   ('Brendan Rodgers', 'PERSON'),
#   ('Celtic', 'NORP'),
#   ('9m', 'MONEY')],
#  [('Sadio Mane', 'PERSON'), ('Liverpool', 'GPE'), ('Bayern Munich', 'PERSON')],
#  [('Liverpool', 'GPE')],
#  [('Liverpool', 'GPE'), ('Tottenham', 'GPE'), ('Premier League', 'ORG')],
#  [('Premier League', 'ORG'),
#   ('Liverpool', 'GPE'),
#   ('Tottenham', 'GPE'),
#   ('Anfield', 'GPE')],
#  [('Raheem Sterling', 'PERSON'),
#   ('Manchester City', 'GPE'),
#   ('Watford', 'PERSON')],
#  [('Cardiff', 'GPE'), ('West Ham', 'GPE')],
#  [('Jordan Pickford', 'PERSON'), ('Newcastle', 'GPE'), ('Everton', 'PERSON')],
#  [('Jamie Vardy', 'PERSON'), ('100th Leicester', 'ORG'), ('Fulham', 'PERSON')],
#  [('Hibernian', 'ORG'), ('Marc McNulty', 'PERSON')],
#  [('Manchester United', 'ORG'), ('Premier League', 'ORG')],
#  [('Unai Emery', 'PERSON'), ('Rennes', 'GPE'), ('Manchester United', 'ORG')],
#  [('Callum Wilson', 'PERSON'),
#   ('England', 'GPE'),
#   ('Bournemouth', 'GPE'),
#   ('Huddersfield', 'GPE')],
#  [('David Luiz', 'PERSON'),
#   ('Chelsea', 'PERSON'),
#   ('Maurizio Sarri', 'PERSON')],
#  [('Mauricio Pochettino', 'PERSON'),
#   ('Tottenham', 'GPE'),
#   ('Southampton', 'GPE')],
#  [('Liverpool', 'GPE'), ('Shamal George', 'PERSON')],
#  [('Manchester United', 'ORG'), ('FA Cup', 'EVENT')],
#  [('Champions League', 'ORG'),
#   ('Tottenham', 'GPE'),
#   ('Man City', 'GPE'),
#   ('Man Utd', 'PERSON'),
#   ('Barcelona', 'GPE'),
#   ('Liverpool', 'GPE'),
#   ('Porto', 'GPE')],
#  [('Chelsea', 'ORG'), ('Eden Hazard', 'GPE'), ('Fifa', 'GPE')],
#  [('Get Telegraph Football WhatsApp', 'ORG'),
#   ('Premier League and Champions League', 'ORG')],
#  [('Declan Rice', 'PERSON'), ('England', 'GPE')],
#  [('Manchester Uniteds', 'ORG'), ('FA Cup', 'EVENT')],
#  [('Ole Gunnar Solskjaer', 'PERSON'), ('Manchester United', 'GPE')],
#  [('Man Utd', 'PERSON'),
#   ('Paris', 'GPE'),
#   ('St-Germain', 'PERSON'),
#   ('Europe', 'LOC'),
#   ('VAR', 'ORG')],
#  [('Matteo Guendouzi', 'PERSON'), ('Rennes', 'GPE')],
#  [('Alex Telles', 'PERSON'), ('VAR', 'ORG'), ('Porto past Roma', 'ORG')],
#  [('Germany', 'GPE'),
#   ('Dutch', 'NORP'),
#   ('Nico Schulzs', 'PERSON'),
#   ('Amsterdam', 'GPE')],
#  [('Bert Trautmann', 'PERSON'),
#   ('The Keeper FAO Manchester City', 'WORK_OF_ART')],
#  [('Callum Hudson-Odoi', 'PERSON'), ('England', 'GPE'), ('Montenegro', 'GPE')],
#  [('Gibraltar', 'GPE')],
#  [('Callum Hudson-Odoi', 'PERSON'), ('England', 'GPE')],
#  [('Brendan Rodgers', 'PERSON'),
#   ('Jamie Vardy', 'PERSON'),
#   ('Premier League', 'ORG')],
#  [('Aberdeen', 'GPE'), ('Glasgow', 'GPE')],
#  [('Manchester City', 'GPE'), ('Juventus', 'ORG')],
#  [('Man United', 'PERSON'), ('De Gea', 'ORG')],
#  [('Gunnar Solskjaer', 'ORG'), ('Manchester United', 'ORG')],
#  [('Bernd Leno', 'PERSON'),
#   ('Arsenal', 'PERSON'),
#   ('Manchester United', 'ORG'),
#   ('FA Cup', 'EVENT'),
#   ('Emirates', 'GPE')],
#  [('Javi Gracia', 'PERSON'),
#   ('Pep Guardiola', 'PERSON'),
#   ('Raheem Sterling', 'PERSON')],
#  [('Roberto Firmino', 'PERSON'),
#   ('Sadio Mane', 'PERSON'),
#   ('Burnley', 'PERSON'),
#   ('Liverpool', 'GPE')],
#  [('Eden Hazard', 'ORG'), ('Chelsea', 'ORG')],
#  [('Marko Arnautovic', 'PERSON'), ('West Ham', 'ORG')],
#  [('Newcastle', 'GPE'),
#   ('Salomon Rondon', 'ORG'),
#   ('Rafa Benitez', 'PERSON'),
#   ('Isaac Hayden', 'PERSON')],
#  [('Chelsea', 'ORG'), ('Everton', 'ORG')],
#  [('Watford', 'ORG'), ('Heurelho Gomes', 'PERSON'), ('FA Cup', 'EVENT')],
#  [('Javier Hernandez', 'PERSON'),
#   ('West Ham', 'GPE'),
#   ('Huddersfield', 'ORG')],
#  [('Manchester City', 'GPE'), ('Chelsea', 'PERSON')],
#  [('Fifa', 'ORG'), ('David Ospina', 'PERSON'), ('Napoli', 'GPE')],
#  [('Leicester', 'GPE'), ('Wes Morgan', 'PERSON'), ('Burnley', 'PERSON')],
#  [('Leeds', 'GPE'),
#   ('Sheffield United', 'PERSON'),
#   ('Chris Wilder', 'PERSON')],
#  [('Crucial', 'ORG'), ('Burnley', 'PERSON')],
#  [('Conor Coady', 'PERSON'), ('Man Utd', 'PERSON')],
#  [('Declan Rice', 'PERSON'),
#   ('Mark Noble', 'PERSON'),
#   ('West Ham', 'LOC'),
#   ('Newcastle', 'GPE')],
#  [('Ole Gunnar Solskjaer', 'PERSON'),
#   ('Man Utd', 'ORG'),
#   ('European', 'NORP'),
#   ('Paris', 'GPE'),
#   ('St-Germain', 'PERSON')],
#  [('Brendan Rodgers', 'PERSON'),
#   ('Jamie Vardy', 'PERSON'),
#   ('Leicester', 'GPE')],
#  [('Andre Gray', 'PERSON'),
#   ('Watford', 'ORG'),
#   ('Brendan Rodgers', 'PERSON'),
#   ('Leicester', 'GPE')],
#  [('Alex Oxlade-Chamberlain', 'PERSON')],
#  [('Liverpool', 'GPE'),
#   ('Andrew Robertson', 'PERSON'),
#   ('Marco Silva', 'PERSON')],
#  [('Kepa Arrizabalaga', 'PERSON')],
#  [('John Ruddy', 'PERSON')],
#  [('Brighton', 'ORG'),
#   ('Glenn Murray', 'PERSON'),
#   ('Florin Andone', 'PERSON')],
#  [('Nathan Ake', 'PERSON'),
#   ('Jose Mourinho', 'PERSON'),
#   ('Chelsea', 'PERSON')],
#  [('Madrid', 'GPE'), ('Barcelona', 'GPE'), ('El Clasico', 'ORG')],
#  [('Tottenham', 'GPE')],
#  [('Brendan Rodgers', 'PERSON'),
#   ('Celtic', 'NORP'),
#   ('Leicester City', 'GPE')],
#  [('English Football League', 'ORG'), ('Championship', 'ORG')],
#  [('England', 'GPE'), ('USA', 'GPE'), ('Phil Neville', 'PERSON')],
#  [('London', 'GPE')],
#  [('Man City', 'PERSON'), ('Liverpool', 'GPE'), ('Pablo Zabaleta', 'PERSON')],
#  [('Real Madrid', 'ORG')],
#  [('Tottenham', 'PERSON'),
#   ('Mauricio Pochettino', 'PERSON'),
#   ('Mike Dean', 'PERSON')],
#  [('Ajax', 'LOC'), ('Real Madrid', 'ORG'), ('Champions League', 'ORG')],
#  [('Ole Gunnar Solskjaer', 'PERSON'), ('Manchester United', 'ORG')],
#  [('Alexis Sanchez', 'PERSON'), ('Manchester United', 'GPE')],
#  [('the Premier League', 'ORG')],
#  [('Champions League', 'ORG'),
#   ('Porto', 'PERSON'),
#   ('Manchester United', 'ORG'),
#   ('PSG', 'ORG')],
#  [('Manchester United', 'ORG'),
#   ('100m', 'MONEY'),
#   ('Jadon Sancho', 'PERSON'),
#   ('French', 'NORP'),
#   ('PSG', 'ORG')],
#  [('Ole Gunnar Solskjaer', 'PERSON'), ('Man Utd', 'PERSON')],
#  [],
#  [('Manchester City', 'GPE')],
#  [('Premier League', 'ORG')],
#  [('Chelsea', 'PERSON')],
#  [('Tottenham', 'GPE'), ('London', 'GPE')],
#  [('Race for Champions League', 'ORG'),
#   ('Chelsea', 'ORG'),
#   ('Man Utd', 'PERSON'),
#   ('Tottenham', 'GPE')],
#  [('Tottenham', 'GPE'), ('Chelsea', 'PERSON')],
#  [('Tottenham', 'GPE')],
#  [('Chelsea', 'ORG'),
#   ('Maurizio Sarri', 'PERSON'),
#   ('Kepa Arrizabalaga', 'PERSON')],
#  [('Premier League', 'ORG'),
#   ('Tottenham', 'GPE'),
#   ('Manchester City', 'GPE'),
#   ('Manchester Utd', 'ORG')],
#  [('Brendan Rodgers', 'PERSON'),
#   ('Celtic', 'NORP'),
#   ('Leicester', 'GPE'),
#   ('Watford', 'ORG')],
#  [('Everton vs Liverpool', 'ORG'), ('Premier League', 'ORG')],
#  [('Guardiola', 'PERSON'), ('Man City', 'GPE'), ('Europe', 'LOC')],
#  [],
#  [('Jurgen Klopp', 'PERSON'),
#   ('Champions League', 'ORG'),
#   ('Premier League', 'ORG')],
#  [('Aaron Lennon', 'PERSON')],
#  [('Everton', 'ORG'), ('Marco Silva', 'PERSON'), ('Lee Mason', 'PERSON')],
#  [('Rio Ferdinand', 'PERSON'),
#   ('Solskjaer', 'PERSON'),
#   ('Manchester United', 'ORG')],
#  [('Champions League', 'ORG')],
#  [('Manchester United', 'ORG'), ('Ole Gunnar Solskjaer', 'PERSON')],
#  [('Declan Rice', 'PERSON'),
#   ('West Ham', 'LOC'),
#   ('England', 'GPE'),
#   ('Mark Noble', 'PERSON')],
#  [('Aaron Wan-Bissaka', 'PERSON'),
#   ('England', 'GPE'),
#   ('Gareth Southgate', 'PERSON')],
#  [('Jadon Sancho', 'PERSON'),
#   ('Manchester United', 'GPE'),
#   ('Dortmund', 'GPE')],
#  [('Chelsea', 'PERSON'), ('London', 'GPE'), ('Fulham', 'GPE')],
#  [('Mauricio Pochettino', 'PERSON'), ('Danny Rose', 'PERSON')],
#  [('Leicester City', 'GPE'),
#   ('Brendan Rodgers', 'PERSON'),
#   ('Wes Morgan', 'PERSON')],
#  [('Manchester United', 'ORG'), ('Premier League', 'ORG')],
#  [('Rafael Benitez', 'PERSON'), ('Newcastle', 'GPE')],
#  [('Chelsea', 'ORG'), ('Maurizio Sarri', 'PERSON')],
#  [('Fifa', 'ORG')],
#  [('Everton', 'ORG'), ('Marco Silva', 'PERSON'), ('Richarlison', 'PERSON')],
#  [('Premier League', 'ORG')],
#  [('Cardiff', 'GPE'), ('Emiliano Sala', 'PERSON')],
#  [('Liverpool', 'GPE'), ('Fulham', 'GPE')],
#  [('Everton', 'ORG'), ('Ross Barkley', 'PERSON'), ('Goodison Park', 'GPE')],
#  [('James Ward-Prowse', 'PERSON')],
#  [('Premier League', 'ORG')],
#  [('Premier League', 'ORG'),
#   ('Manchester City', 'GPE'),
#   ('Tottenham for Champions League', 'ORG')],
#  [('Ole Gunnar Solskjaer', 'PERSON'), ('Manchester United', 'ORG')],
#  [('Liverpool', 'GPE'),
#   ('Barcelona', 'GPE'),
#   ('Luis Suarez', 'PERSON'),
#   ('Philippe Coutinho', 'PERSON')],
#  [('Liverpool', 'GPE'), ('Manchester City', 'GPE'), ('Premier League', 'ORG')],
#  [('Premier League', 'ORG'), ('Liverpool', 'GPE'), ('Chelsea', 'PERSON')],
#  [('Man Utd', 'PERSON'), ('West Ham', 'ORG'), ('Premier League', 'ORG')],
#  [('Ronny Rosenthal', 'PERSON'), ('Liverpool', 'GPE')],
#  [('Pierre-Emerick Aubameyang', 'PERSON')],
#  [('Eden Hazard', 'ORG'), ('West Ham', 'LOC'), ('Chelsea', 'PERSON')],
#  [('Neil Warnock', 'PERSON'), ('FA', 'ORG'), ('Craig Pawson', 'PERSON')],
#  [('Cardiff', 'GPE'), ('Brighton', 'LOC')],
#  [('Ashley Young', 'PERSON'),
#   ('Manchester United', 'ORG'),
#   ('Barcelona', 'GPE')],
#  [('Champions League', 'ORG')],
#  [('Manchester City', 'GPE'), ('Spurs', 'ORG')],
#  [('Ajax', 'LOC'), ('Europe', 'LOC')],
#  [('Granit Xhaka', 'PERSON'), ('Arsenal', 'PERSON'), ('Watford', 'ORG')],
#  [('Brighton', 'ORG'), ('Premier League', 'ORG')],
#  [('Troy Deeney', 'PERSON'), ('Watford', 'ORG'), ('Ben Foster', 'PERSON')],
#  [('Barnsley', 'PERSON'),
#   ('EFL', 'ORG'),
#   ('FA', 'ORG'),
#   ('Joey Barton', 'PERSON'),
#   ('Daniel Stendel', 'PERSON')],
#  [('Charlton', 'ORG'), ('Europe', 'LOC')],
#  [('Middlesbrough', 'ORG'), ('Steve Gibson', 'PERSON'), ('EFL', 'ORG')],
#  [('Jurgen Klopp', 'PERSON'), ('Anfield', 'PERSON')],
#  [('Mohamed Salah', 'PERSON'), ('Liverpool', 'GPE'), ('Chelsea', 'PERSON')],
#  [('Raheem Sterling', 'ORG'),
#   ('Manchester City', 'GPE'),
#   ('Crystal Palace', 'FAC')],
#  [('Barnsley', 'ORG'),
#   ('Daniel Stendel', 'PERSON'),
#   ('Joey Barton', 'PERSON')],
#  [('Barcelona', 'ORG'), ('Manchester United', 'ORG')],
#  [('Chelsea', 'PERSON'), ('Liverpool', 'GPE')],
#  [('Liverpool', 'GPE'), ('Chelsea', 'PERSON'), ('Premier League', 'ORG')],
#  [('Crystal Palace', 'FAC'), ('Man City', 'GPE'), ('Premier League', 'ORG')],
#  [('the Scottish Cup', 'EVENT'), ('Inverness', 'GPE')],
#  [('Watford', 'GPE'), ('Napoli', 'GPE')],
#  [('Scott Parker', 'PERSON'), ('Fulham', 'GPE'), ('Everton', 'PERSON')],
#  [('Burnley', 'PERSON'), ('Cardiff', 'GPE'), ('Neil Warnock', 'PERSON')],
#  [('Nathan Redmond', 'PERSON'),
#   ('Southampton', 'GPE'),
#   ('Premier League', 'ORG')],
#  [('Lucas Moura', 'PERSON'), ('Tottenham', 'GPE'), ('Huddersfield', 'GPE')],
#  [('Jan Vertonghen', 'PERSON'), ('VAR', 'ORG'), ('Manchester City', 'GPE')],
#  [('Eden Hazard', 'ORG'), ('Chelsea', 'ORG'), ('Real Madrid', 'ORG')],
#  [('Ajax', 'ORG'), ('Juventus', 'ORG'), ('Champions League', 'ORG')],
#  [('Ilkay Gundogan', 'PERSON'),
#   ('Manchester City', 'GPE'),
#   ('Champions League', 'ORG')],
#  [('Man City', 'GPE')],
#  [('Maurizio Sarri', 'PERSON'), ('Chelsea', 'PERSON'), ('Liverpool', 'GPE')],
#  [('Unai Emery', 'PERSON'), ('Javi Gracia', 'PERSON')],
#  [('Fulham', 'PERSON'), ('Tom Cairney', 'PERSON'), ('Scott Parker', 'PERSON')],
#  [('Son Heung-min', 'PERSON'), ('Tottenham', 'PERSON')],
#  [('Roy Hodgson', 'PERSON')],
#  [('Paul Pogba', 'PERSON'),
#   ('Manchester United', 'ORG'),
#   ('West Ham', 'PERSON')],
#  [('Bournemouth', 'PERSON'), ('Brighton', 'GPE')],
#  [('Chelsea', 'ORG'), ('Manchester City', 'GPE'), ('FA Cup', 'EVENT')],
#  [('West Ham', 'PERSON'), ('Cho So-hyun', 'PERSON'), ('FA Cup', 'EVENT')],
#  [('Barnsley', 'PERSON'), ('Joey Barton', 'PERSON')],
#  [('Jordan Henderson', 'PERSON'), ('Liverpool', 'GPE')],
#  [('Michael Keane', 'PERSON'),
#   ('Everton European', 'ORG'),
#   ('VAR', 'ORG'),
#   ('England', 'GPE')],
#  [('Jurgen Klopp', 'PERSON'), ('Jordan Henderson', 'PERSON')],
#  [('Harry Winks', 'PERSON'),
#   ('Tottenham', 'PERSON'),
#   ('Manchester City', 'GPE'),
#   ('Champions League', 'ORG')],
#  [('Neil Lennon', 'PERSON'),
#   ('Brendan Rodgers', 'PERSON'),
#   ('Celtic', 'NORP')],
#  [('Unai Emery', 'PERSON'), ('Arsenal', 'ORG')],
#  [('Mo Salah', 'PERSON'), ('Liverpool', 'GPE'), ('Southampton', 'GPE')],
#  [('Joao', 'PERSON'), ('Moutinho', 'PERSON')],
#  [('Premier League', 'ORG'), ('Champions League', 'ORG')],
#  [('Tottenham', 'GPE'),
#   ('30m', 'MONEY'),
#   ('Andre Gomes', 'PERSON'),
#   ('Everton', 'ORG')],
#  [('Southampton', 'GPE'), ('Liverpool', 'GPE'), ('Premier League', 'ORG')],
#  [('Robbie Dennison', 'PERSON')],
#  [('Watford', 'ORG'), ('Jose Holebas', 'PERSON'), ('Greece', 'GPE')],
#  [('Ander Herrera', 'PERSON'), ('PSG', 'ORG'), ('Manchester United', 'ORG')],
#  [('Norwich City', 'GPE')],
#  [('Cristiano Ronaldo', 'PERSON'), ('Ajax', 'ORG'), ('Turin', 'GPE')],
#  [('Sheffield United', 'PERSON'), ('Michael Morrison', 'PERSON')],
#  [('Liverpool', 'GPE')],
#  [('Everton vs Manchester United', 'ORG')],
#  [('Manchester United', 'ORG'), ('the Women Super League', 'ORG')],
#  [('Moussa Sissoko', 'PERSON'), ('Spurs', 'ORG')],
#  [('Chris Hughton', 'PERSON'), ('Brighton', 'GPE'), ('Cardiff', 'GPE')],
#  [('Fleetwood', 'ORG'), ('Joey Barton', 'PERSON')],
#  [('Uefa', 'ORG'),
#   ('Fernando Llorente', 'PERSON'),
#   ('Manchester City', 'GPE')],
#  [('Erik Lamela', 'PERSON'), ('VAR', 'ORG'), ('Tottenham', 'PERSON')],
#  [('Madrid', 'GPE'), ('Eden Hazard', 'GPE'), ('100m', 'MONEY')],
#  [('Eddie Howe', 'PERSON'), ('Bournemouth', 'PERSON')],
#  [('Andros Townsend', 'PERSON'), ('Wilfried Zaha', 'PERSON')],
#  [('Leeds', 'GPE'), ('Pablo Hernandez', 'PERSON'), ('Garry Monk', 'PERSON')],
#  [('Kevin De Bruyne', 'PERSON'), ('Tottenham', 'PERSON')],
#  [('Jamie Vardy', 'PERSON'),
#   ('Leicester City', 'GPE'),
#   ('Huddersfield', 'GPE')],
#  [('Burnley', 'PERSON'), ('Premier League', 'ORG'), ('Bournemouth', 'GPE')],
#  [('Everton', 'ORG'),
#   ('5m', 'MONEY'),
#   ('Inter Milan', 'ORG'),
#   ('Romelu Lukaku', 'PERSON'),
#   ('Manchester United', 'GPE')],
#  [('Wembley', 'GPE')],
#  [('Watford', 'ORG'), ('FA Cup', 'EVENT'), ('Wolves', 'ORG')],
#  [('Exclusive Fabinho', 'ORG'), ('Liverpool', 'GPE')],
#  [('Tottenham Hotspur', 'PERSON'), ('Huddersfield', 'GPE')],
#  [('Liverpool', 'GPE'), ('Chelsea', 'PERSON')],
#  [('Jurgen Klopp', 'PERSON')],
#  [('Neil Warnock', 'PERSON'), ('Cardiff City', 'GPE')],
#  [('Birmingham', 'GPE'), ('Che Adams', 'PERSON'), ('Premier League', 'ORG')],
#  [('Crystal Palace', 'FAC'), ('Man City', 'GPE'), ('Premier League', 'ORG')],
#  [('Alexsandar Mitrovic', 'PERSON'), ('West Ham', 'GPE')],
#  [('Maurizio Sarri', 'PERSON'),
#   ('Chelsea', 'PERSON'),
#   ('Eden Hazard', 'FAC'),
#   ('Real Madrid', 'ORG')],
#  [('Marbella', 'PERSON'), ('Europe', 'LOC'), ('FA Cup', 'EVENT')],
#  [('Virgil van Dijk', 'PERSON'),
#   ('Raheem Sterling', 'PERSON'),
#   ('PFA Player', 'ORG'),
#   ('the Year', 'EVENT')],
#  [('Chelsea', 'ORG'), ('Danny Drinkwater', 'PERSON')],
#  [('Jim White', 'PERSON'),
#   ('British', 'NORP'),
#   ('Tottenham', 'GPE'),
#   ('Manchester City', 'GPE'),
#   ('European', 'NORP')],
#  [('Everton as', 'ORG'), ('Marco Silva', 'PERSON')],
#  [('Luka Milivojevic', 'PERSON'), ('Crystal Palace', 'PRODUCT')],
#  [('Tottenham', 'GPE'),
#   ('Manchester City', 'GPE'),
#   ('Champions League', 'ORG')],
#  [('Liverpool', 'GPE'), ('Porto Champions League', 'ORG')],
#  [('Ole Gunnar Solskjaer', 'PERSON'), ('Molde', 'GPE'), ('Man Utd', 'PERSON')],
#  [('Manchester City', 'GPE'), ('Liverpool', 'GPE')],
#  [('Guardiola', 'PERSON'), ('Man City', 'GPE')],
#  [('Premier League', 'ORG'),
#   ('Manchester City', 'GPE'),
#   ('Leicester', 'GPE'),
#   ('Manchester United', 'GPE')],
#  [('Gary Neville', 'PERSON'),
#   ('Mauricio Pochettino', 'PERSON'),
#   ('Man Utd', 'PERSON'),
#   ('Ole Gunnar Solskjaer', 'PERSON')],
#  [('Man City', 'GPE')],
#  [('Jurgen Klopp', 'PERSON'), ('Liverpool', 'GPE')],
#  [('Football Association', 'ORG'), ('FA Cup', 'EVENT')],
#  [('Manchester City vs Arsenal', 'GPE'), ('Premier League', 'ORG')],
#  [('Manchester United', 'ORG'),
#   ('Liverpool', 'GPE'),
#   ('Premier League', 'ORG')],
#  [('Liverpool', 'GPE'),
#   ('Trent Alexander-Arnold', 'PERSON'),
#   ('Trafford', 'GPE')],
#  [('Jurgen Klopp', 'PERSON'),
#   ('Ole Gunnar Solskjaer', 'PERSON'),
#   ('Manchester United', 'ORG')],
#  [('Chelsea', 'PERSON'), ('Manchester City', 'GPE'), ('Carabao Cup', 'EVENT')],
#  [('Chelsea', 'PERSON'),
#   ('Steve Holland', 'PERSON'),
#   ('Maurizio Sarri', 'PERSON')],
#  [('Mesut Ozil', 'PERSON'),
#   ('Arsenal', 'PERSON'),
#   ('Sokratis Papastathopoulos', 'PERSON')],
#  [('Manchester United v Liverpool', 'ORG'), ('Premier League', 'ORG')],
#  [('Chelsea', 'ORG'), ('Fifa', 'GPE')],
#  [('Chelsea', 'PERSON'),
#   ('Man City', 'GPE'),
#   ('Maurizio Sarri', 'PERSON'),
#   ('Carabao Cup', 'EVENT')],
#  [('Chelsea', 'ORG'), ('Manchester United', 'ORG')],
#  [('Georginio Wijnaldum', 'PERSON'), ('Liverpool', 'GPE')],
#  [('Chelsea', 'ORG'),
#   ('Manchester City', 'GPE'),
#   ('Bernardo Silva', 'PERSON')],
#  [('Roberto Pereyra', 'PERSON'), ('Emiliano Sala', 'PERSON')],
#  [('Millwall', 'ORG'), ('FA Cup', 'EVENT'), ('Everton', 'PERSON')],
#  [('Chelsea', 'PERSON'), ('Manchester City', 'GPE'), ('Carabao Cup', 'EVENT')],
#  [('Chelsea', 'PERSON'),
#   ('Maurizio Sarri', 'PERSON'),
#   ('Man Utd', 'PERSON'),
#   ('FA Cup', 'EVENT')],
#  [('Manchester United', 'ORG')],
#  [('Man Utd', 'PERSON'), ('Millwall', 'PERSON'), ('Brighton', 'GPE')],
#  [('Phil Neville', 'PERSON'), ('England Women', 'ORG'), ('US', 'GPE')],
#  [('Chelsea', 'ORG'), ('Maurizio Sarri', 'PERSON')],
#  [('Anthony Martial', 'PERSON'),
#   ('Ole Gunnar Solskjaer', 'PERSON'),
#   ('Man Utd', 'PERSON')],
#  [('Jose', 'PERSON'), ('Paul Scholes', 'PERSON'), ('Oldham', 'GPE')],
#  [('Rafael Benitez', 'PERSON'),
#   ('Wolves', 'ORG'),
#   ('Newcastle', 'GPE'),
#   ('Martin Dubravka', 'PERSON')],
#  [('Mauricio Pochettino', 'PERSON'), ('SonHeung-min', 'WORK_OF_ART')],
#  [('Man Utd', 'PERSON'), ('Ole Gunnar Solskjaer', 'PERSON'), ('PSG', 'ORG')],
#  [('Maurizio Sarri', 'PERSON'),
#   ('Chelsea', 'PERSON'),
#   ('Italian', 'NORP'),
#   ('Europa League', 'ORG')],
#  [('Leicester', 'GPE'), ('Jamie Vardy', 'PERSON')],
#  [('Paul Scholes', 'PERSON'), ('Oldham Athletic', 'ORG')],
#  [('Martin Dubravka', 'PERSON'), ('Newcastle', 'GPE')],
#  [('PFA', 'ORG'), ('Gordon Taylor', 'PERSON')],
#  [('Liverpool', 'GPE'),
#   ('Bayern', 'NORP'),
#   ('European Cup', 'EVENT'),
#   ('Richard Money', 'PERSON')],
#  [('Celtic', 'NORP'),
#   ('Valencia', 'GPE'),
#   ('Ryan Christie', 'PERSON'),
#   ('Scottish', 'NORP'),
#   ('European', 'NORP')],
#  [('Phil Foden', 'PERSON'),
#   ('Man City', 'PERSON'),
#   ('FA Cup', 'EVENT'),
#   ('Newport', 'GPE')],
#  [('Granit Xhaka - the', 'PERSON'), ('Unai Emery', 'PERSON')],
#  [('Claude Puel', 'PERSON'), ('Crystal Palace', 'FAC'), ('Leicester', 'GPE')],
#  [('Chelsea', 'PERSON'), ('Manchester City', 'GPE'), ('Carabao Cup', 'EVENT')],
#  [('Bournemouth', 'GPE'), ('Wolves', 'ORG')],
#  [('Guardiola', 'PERSON'), ('Chelsea', 'PERSON'), ('Carabao Cup', 'EVENT')],
#  [('Gunnar Solskjaer', 'PERSON'), ('Man Utd', 'ORG'), ('Liverpool', 'GPE')],
#  [('Jurgen Klopp', 'PERSON'),
#   ('Liverpool', 'GPE'),
#   ('Manchester United', 'GPE')],
#  [('Leah Williamson', 'PERSON'),
#   ('League Cup', 'EVENT'),
#   ('Arsenal', 'PERSON')],
#  [('Willie McKay', 'PERSON'), ('Emiliano Sala', 'PERSON')],
#  [('Manchester United', 'ORG'),
#   ('Liverpool', 'GPE'),
#   ('Premier League', 'ORG')],
#  [('Leicester City', 'GPE'),
#   ('Claude Puel', 'PERSON'),
#   ('Brendan Rodgers', 'PERSON')],
#  [('Newport County', 'GPE'), ('Manchester City', 'GPE')],
#  [('Newport County', 'GPE'), ('Manchester City', 'GPE')],
#  [('AFC Wimbledon', 'ORG'), ('Anthony Wordsworth', 'PERSON')],
#  [('Steven Gerrard', 'PERSON'),
#   ('Rangers', 'ORG'),
#   ('St Johnstone', 'PERSON')],
#  [('Guardiola', 'PERSON'), ('Man City', 'GPE'), ('Fail Newport', 'ORG')],
#  [('Watford', 'ORG'), ('QPR', 'ORG')],
#  [('AFC Wimbledon', 'ORG'), ('Scott Wagstaff', 'PERSON'), ('FA Cup', 'EVENT')],
#  [('Bristol City', 'GPE'), ('England', 'GPE'), ('FA Cup', 'EVENT')],
#  [('Chelsea', 'PERSON'),
#   ('Maurizio Sarri', 'PERSON'),
#   ('Europa League', 'ORG')],
#  [('Bernardo Silva', 'PERSON'),
#   ('VAR', 'ORG'),
#   ('Man City', 'GPE'),
#   ('Schalke', 'PRODUCT')],
#  [('Diego Simeone', 'PERSON')],
#  [('Manchester United v Liverpool', 'ORG')],
#  [('Premier League', 'ORG'),
#   ('Hugo Lloris', 'PERSON'),
#   ('Alisson', 'PERSON'),
#   ('David De Gea', 'PERSON'),
#   ('Kepa', 'PERSON')],
#  [('Nantes', 'GPE'), ('18300', 'MONEY'), ('Emiliano Sala', 'PERSON')],
#  [('Manchester United', 'ORG'), ('FA Cup', 'EVENT'), ('BBC', 'ORG')],
#  [('Manchester City', 'GPE'), ('Puma', 'ORG'), ('650 million', 'MONEY')],
#  [('Mesut Ozil', 'PERSON'), ('Ozil', 'PERSON')],
#  [('Manchester United', 'ORG'), ('Crystal Palace', 'FAC')],
#  [('Maurizio Sarri', 'PERSON'), ('Chelsea', 'PERSON')],
#  [('Liverpool', 'GPE'), ('Watford', 'GPE')],
#  [('Willy Caballero', 'PERSON'),
#   ('Kepa', 'ORG'),
#   ('Wembley', 'GPE'),
#   ('Chelsea', 'PERSON')],
#  [('Bournemouth', 'PERSON')],
#  [('Southampton', 'GPE'), ('Fulham', 'GPE')],
#  [('Claudio Ranieri', 'PERSON'), ('Italian', 'NORP'), ('Fulham', 'GPE')],
#  [('Sergio Aguero', 'PERSON'),
#   ('West Ham', 'PERSON'),
#   ('Man City', 'GPE'),
#   ('Liverpool', 'GPE')],
#  [('Neil Warnock', 'PERSON'), ('Victor Camarasa', 'PERSON')],
#  [('Gylfi Sigurdsson', 'PERSON'), ('Everton', 'ORG'), ('Cardiff', 'GPE')],
#  [('Chelsea', 'ORG'), ('Manchester United', 'ORG')],
#  [('Premier League', 'ORG'),
#   ('Liverpool', 'GPE'),
#   ('Manchester City', 'GPE'),
#   ('Manchester Utd', 'ORG'),
#   ('Chelsea', 'ORG'),
#   ('Tottenham', 'PERSON')],
#  [('Fabian Schar', 'PERSON'), ('Newcastle', 'GPE'), ('Burnley', 'PERSON')],
#  [('Mike Dean', 'PERSON'),
#   ('Spurs', 'ORG'),
#   ('Chelsea', 'PERSON'),
#   ('Mauricio Pochettino', 'PERSON')],
#  [('Leicester', 'GPE'), ('Brendan Rodgers', 'PERSON'), ('Brighton', 'GPE')],
#  [('Fulham', 'PERSON'), ('Tom Cairney', 'PERSON')],
#  [],
#  [('Southampton', 'GPE')],
#  [('Sean Longstaff', 'PERSON'), ('Newcastle United', 'GPE')],
#  [('Premier League', 'ORG'), ('FA', 'ORG')],
#  [('Alexis Sanchez', 'PERSON'),
#   ('Romelu Lukaku', 'PERSON'),
#   ('Man Utd', 'PERSON'),
#   ('Ole Gunnar Solskjaer', 'ORG')],
#  [('Liverpool', 'GPE'), ('Man Utd', 'PERSON')],
#  [('Kepa Arrizabalaga', 'PERSON'), ('Maurizio Sarris', 'PERSON')],
#  [('Unai Emery', 'PERSON'), ('Arsenal', 'PERSON')],
#  [],
#  [('Tottenham', 'GPE'),
#   ('Son', 'PERSON'),
#   ('Dortmund', 'GPE'),
#   ('one foot', 'QUANTITY')],
#  [('Maurico Pochettino', 'PERSON'),
#   ('Tottenham', 'GPE'),
#   ('Dortmund', 'GPE'),
#   ('Wembley', 'GPE')],
#  [('Maurizio Sarri', 'PERSON'), ('Chelsea', 'PERSON')],
#  [('Jan Vertonghen', 'PERSON')],
#  [('Alex Ferguson', 'PERSON'),
#   ('Manchester United', 'ORG'),
#   ('Paul Scholes', 'PERSON')],
#  [('Anthony Martial', 'PERSON'),
#   ('Jesse Lingard', 'PERSON'),
#   ('Man Utd', 'PERSON'),
#   ('FA Cup', 'EVENT'),
#   ('Chelsea', 'ORG')],
#  [('Jurgen Klopp', 'PERSON'), ('Liverpool', 'GPE'), ('Bournemouth', 'PERSON')],
#  [('Man City', 'GPE'), ('Pep Guardiola', 'PERSON')],
#  [('England', 'GPE'), ('Dortmund', 'GPE')],
#  [('Rangers', 'ORG'),
#   ('Gary McAllister', 'PERSON'),
#   ('Kilmarnock Cup', 'EVENT')],
#  [('Wilfried', 'PERSON'),
#   ('Zaha', 'ORG'),
#   ('Crystal Palace', 'PRODUCT'),
#   ('West Ham', 'LOC')],
#  [('Marco Silva', 'PERSON'),
#   ('Watford', 'ORG'),
#   ('Andre Gray', 'PERSON'),
#   ('Everton', 'PERSON')],
#  [('Fulham', 'GPE'), ('Paul Pogba', 'PERSON'), ('Man Utd', 'PERSON')],
#  [('Manchester City', 'GPE'),
#   ('Chelsea', 'PERSON'),
#   ('Premier League', 'ORG')],
#  [('Huddersfield', 'GPE')],
#  [('Cardiff City', 'GPE'), ('English', 'NORP'), ('Emiliano Sala', 'PERSON')],
#  [('Hugo Lloris', 'PERSON'), ('France', 'GPE'), ('World Cup', 'EVENT')],
#  [('Chelsea', 'PERSON'), ('Malmo', 'GPE')],
#  [('Celtic', 'NORP'),
#   ('Europe', 'LOC'),
#   ('Valencia', 'GPE'),
#   ('Denis Cherysev', 'PERSON'),
#   ('Ruben Sobrino', 'PERSON')],
#  [('Latest Manchester United', 'ORG'),
#   ('196m', 'QUANTITY'),
#   ('Jose Mourinho', 'PERSON')],
#  [('QPR', 'ORG'), ('Grant Hall', 'ORG')],
#  [('Liverpool', 'GPE'), ('Dejan Lovren', 'ORG'), ('Champions League', 'ORG')],
#  [('Newport', 'ORG'),
#   ('Joe Day', 'PERSON'),
#   ('FA Cup', 'EVENT'),
#   ('Middlesbrough', 'GPE')],
#  [('Bernardo Silva', 'PERSON'), ('Man City', 'GPE')],
#  [('Nikita Parris', 'PERSON'),
#   ('Man City Women', 'ORG'),
#   ('Chelsea', 'PERSON'),
#   ('League Cup', 'EVENT')],
#  [],
#  [('Manchester City', 'GPE'),
#   ('Everton', 'ORG'),
#   ('the Premier League', 'ORG')],
#  [('Glenn Murray', 'PERSON'), ('Brighton', 'GPE'), ('West Brom', 'NORP')],
#  [('Celtic', 'NORP'),
#   ('Ryan Christie', 'PERSON'),
#   ('Ollie Burke', 'PERSON'),
#   ('Hibs', 'ORG')],
#  [('Manchester City', 'GPE'),
#   ('Liverpool', 'GPE'),
#   ('Intel', 'ORG'),
#   ('Premier League', 'ORG')],
#  [('Uefa', 'ORG'), ('Fifa', 'ORG')],
#  [],
#  [('Manchester United', 'ORG'), ('Luke Shaw', 'PERSON')],
#  [('Newcastle', 'GPE'), ('Spanish', 'NORP')],
#  [('Premier League', 'ORG'),
#   ('Liverpool', 'GPE'),
#   ('Manchester United', 'ORG'),
#   ('Trafford', 'GPE')],
#  [('Kepa Arrizabalaga', 'PERSON'), ('Chelsea', 'PERSON')],
#  [('Mauricio Pochettino', 'PERSON'), ('Tottenham', 'GPE'), ('FA', 'ORG')],
#  [('Manchester City', 'GPE'),
#   ('Kepa Arrizabalaga', 'PERSON'),
#   ('League Cup', 'EVENT')],
#  [('Jimenez', 'PERSON'), ('Bournemouth', 'GPE')],
#  [('Liverpool', 'GPE'),
#   ('Manchester', 'GPE'),
#   ('Ole Gunnar Solskjaer', 'PERSON')],
#  [('Chris Wilder', 'PERSON'),
#   ('Kieran Dowell', 'PERSON'),
#   ('Sheffield United', 'PERSON')],
#  [('Burnley', 'PERSON'), ('Tom Heaton', 'PERSON'), ('England', 'GPE')],
#  [('Everton', 'ORG'), ('Marco Silva', 'PERSON'), ('Watford', 'PERSON')],
#  [('Guardiola', 'PERSON'), ('Chelsea', 'PERSON'), ('Manchester City', 'GPE')],
#  [('AlexIwobi', 'ORG'), ('Arsenal', 'GPE')],
#  [('Southampton', 'GPE'), ('Cardiff', 'GPE'), ('Emiliano Sala', 'PERSON')],
#  [('Hugo Lloris', 'PERSON'),
#   ('Tottenham', 'GPE'),
#   ('Wembley', 'GPE'),
#   ('Borussia Dortmund', 'ORG')],
#  [('Sergio Aguero', 'PERSON'),
#   ('Manchester City', 'GPE'),
#   ('Chelsea', 'PERSON'),
#   ('Sarri', 'NORP')],
#  [('Chris Wood', 'ORG'), ('Burnley', 'PERSON'), ('Brighton', 'GPE')],
#  [('Cesar Azpilicueta', 'PERSON'), ('Chelsea', 'PERSON'), ('Man City', 'GPE')],
#  [('Crystal Palace', 'ORG'),
#   ('Wilfried Zaha', 'PERSON'),
#   ('West Ham', 'PERSON')],
#  [('Bethany England', 'PERSON'), ('Durham', 'GPE')],
#  [('Gareth Barry', 'PERSON'), ('Premier League', 'ORG'), ('West Brom', 'LOC')],
#  [('Chelsea', 'ORG'), ('Manchester United', 'ORG'), ('FA Cup', 'EVENT')],
#  [('Chelsea', 'ORG'), ('Manchester United', 'ORG'), ('FA Cup', 'EVENT')],
#  [('Bayern Munich', 'PERSON'),
#   ('Joshua Kimmich', 'PERSON'),
#   ('Liverpool', 'GPE')],
#  [],
#  [('Sergio Aguero', 'PERSON'), ('Manchester City', 'GPE')],
#  [('Roy Hodgson', 'PERSON'), ('Crystal Palace', 'ORG')],
#  [('Norwich', 'PERSON'), ('Tim Krul', 'PERSON'), ('Leeds', 'GPE')],
#  [('Liverpool', 'GPE'), ('Joe Gomez', 'PERSON')],
#  [('Manchester United', 'ORG'),
#   ('Casey Stoney', 'PERSON'),
#   ('Brighton  Hove Albion', 'ORG'),
#   ('Women FA Cup', 'ORG')],
#  [('Marco Silva', 'PERSON'), ('Everton', 'PERSON')],
#  [('Unai Emery', 'PERSON')],
#  [('Alexis Sanchez', 'PERSON'),
#   ('Ole Gunnar Solskjaer', 'PERSON'),
#   ('Manchester United', 'ORG')],
#  [('Watford', 'PERSON'),
#   ('Ben Foster', 'PERSON'),
#   ('Edwin Van der Sar', 'PERSON')],
#  [('Joe Cole', 'PERSON'), ('5000', 'MONEY')],
#  [('Premier League', 'ORG'), ('Chelsea', 'PERSON'), ('Tottenham', 'PERSON')],
#  [('Rafael Benitez', 'PERSON'), ('Newcastle', 'GPE')],
#  [('Notts County', 'GPE'), ('the Football League', 'ORG')],
#  [('Premier League', 'ORG'),
#   ('Manchester City', 'GPE'),
#   ('Brighton', 'GPE'),
#   ('Watford', 'ORG')],
#  [('Maurizio Sarri', 'PERSON')],
#  [('Premier League', 'ORG'), ('Tour de France', 'ORG'), ('Yorkshire', 'GPE')],
#  [('FA Cup', 'EVENT')],
#  [('West Ham', 'PERSON'), ('Liverpool', 'GPE')],
#  [('Newport', 'ORG'), ('Cup', 'EVENT')],
#  [('the Premier League', 'ORG')],
#  [],
#  [('QPR', 'ORG'), ('Portsmouth', 'GPE'), ('Watford', 'ORG')],
#  [('Alex Oxlade-Chamberlain', 'PERSON'), ('Liverpool', 'GPE'), ('XI', 'ORG')],
#  [('Rangers', 'ORG'),
#   ('Steven Gerrard', 'PERSON'),
#   ('Steve Clarke', 'PERSON')],
#  [('Exclusive Moussa Sissoko', 'PERSON')],
#  [('Fulham', 'GPE'), ('Claudio Ranieri', 'PERSON')],
#  [('Liverpool', 'GPE'), ('125m', 'MONEY')],
#  [('Phil Jones', 'PERSON'), ('Manchester United', 'ORG')],
#  [('Premier League', 'ORG')],
#  [('Peter Crouch', 'PERSON'),
#   ('Burnley', 'PERSON'),
#   ('Premier League', 'ORG')],
#  [('Michy Batshuayi', 'PERSON'), ('Crystal Palace', 'FAC')],
#  [('Manchester City', 'GPE'), ('Newcastle', 'GPE')],
#  [('Everton', 'ORG'),
#   ('Paris Saint Germains', 'ORG'),
#   ('Idrissa Gueye', 'PERSON')],
#  [('Jurgen Klopp', 'PERSON'),
#   ('Liverpool', 'GPE'),
#   ('Manchester City', 'GPE')],
#  [('Michy Batshuayi', 'PERSON'), ('Crystal Palace', 'ORG')],
#  [('Leicester City', 'GPE'), ('Youri Tielemans', 'PERSON')],
#  [('Crosses', 'PRODUCT'),
#   ('Tottenham', 'PERSON'),
#   ('Borussia Dortmund', 'PERSON')],
#  [('Fabinho', 'ORG'), ('Jurgen Klopp', 'PERSON'), ('Liverpool', 'GPE')],
#  [('Marco Verratti', 'PERSON'), ('the Champions League', 'ORG')],
#  [('Burnley', 'PERSON'), ('Gaetan Bong', 'PERSON')],
#  [('Kylian Mbappe', 'ORG'), ('Manchester United', 'ORG')],
#  [('Paul Scholes', 'PERSON'), ('Oldham', 'GPE'), ('Yeovil', 'GPE')],
#  [('Ole Gunnar Solskjaer', 'PERSON'), ('Man Utd', 'PERSON'), ('PSG', 'ORG')],
#  [('Chelsea', 'PERSON')],
#  [('West Ham United', 'PERSON'),
#   ('Liverpool', 'GPE'),
#   ('Premier League', 'ORG')],
#  [('Mark Noble', 'PERSON'), ('Liverpool', 'GPE'), ('Jurgen Klopp', 'PERSON')],
#  [('Chelsea', 'PERSON'),
#   ('Thibaut Courtois', 'PERSON'),
#   ('Marina Granovskaia', 'PERSON')],
#  [('Bullseye', 'ORG'),
#   ('Newport', 'ORG'),
#   ('Man City', 'GPE'),
#   ('FA Cup', 'EVENT'),
#   ('Middlesbrough', 'GPE')],
#  [('Naby Keita', 'PERSON'), ('West Ham', 'LOC'), ('Liverpool', 'GPE')],
#  [('Jurgen Klopp', 'PERSON'),
#   ('Liverpool', 'GPE'),
#   ('West Ham United', 'ORG')],
#  [('Bernd Leno', 'PERSON'), ('Arsenal', 'PERSON')],
#  [('Portsmouth', 'GPE')],
#  [('Jurgen Klopp', 'PERSON'), ('FA', 'ORG'), ('Liverpool', 'GPE')],
#  [('Troy Deeney', 'PERSON'), ('Everton', 'PERSON'), ('Marco Silva', 'PERSON')],
#  [('Premier League', 'ORG'),
#   ('Manchester City', 'GPE'),
#   ('Chelesa', 'NORP'),
#   ('Bournemouth', 'GPE'),
#   ('Liverpool', 'GPE')],
#  [('Andre Green', 'PERSON'),
#   ('Aston Villa', 'PERSON'),
#   ('Billy Sharp', 'PERSON')],
#  [('Chelsea', 'ORG'),
#   ('Gonzalo Higuain', 'PERSON'),
#   ('Maurizio Sarri', 'PERSON')],
#  [('Manchester City', 'GPE'),
#   ('Chelsea', 'PERSON'),
#   ('Premier League', 'ORG')],
#  [('Gary McAllister', 'PERSON'),
#   ('Rangers', 'ORG'),
#   ('Colombian', 'NORP'),
#   ('Alfredo Morelos', 'PERSON')],
#  [('Steven Gerrard', 'PERSON'), ('Scottish Cup', 'EVENT'), ('Rangers', 'ORG')],
#  [('Jake Livermore', 'PERSON'), ('QPR', 'ORG')],
#  [('Dan Ashworth', 'PERSON'), ('Brighton', 'GPE'), ('Premier League', 'ORG')],
#  [('Guardiola', 'PERSON'), ('Manchester City', 'GPE'), ('Liverpool', 'GPE')],
#  [('Denis Suarez', 'PERSON'),
#   ('Barcelona', 'GPE'),
#   ('Yannick Carrasco', 'PERSON')],
#  [('Newcastle', 'GPE'), ('Man City', 'GPE')],
#  [('Fernando Llorente', 'PERSON'), ('Tottenham', 'GPE'), ('Watford', 'ORG')],
#  [('Chelsea', 'PERSON'), ('Sarriball', 'PERSON'), ('Bournemouth', 'PERSON')],
#  [('Liverpool', 'GPE'), ('Man City', 'GPE'), ('Leicester', 'GPE')],
#  [('Wilfried Zaha', 'PERSON'),
#   ('Southampton', 'GPE'),
#   ('Crystal Palace', 'FAC')],
#  [('Alvaro Morata', 'PERSON'),
#   ('Chelsea', 'PERSON'),
#   ('Angus Gunn', 'PERSON'),
#   ('Southampton', 'GPE')],
#  [('Manchester United', 'ORG'),
#   ('Ole Gunnar Solskjaer', 'PERSON'),
#   ('Rafa Benitez', 'PERSON')],
#  [('Marko Arnautovic', 'PERSON'), ('West Ham', 'ORG'), ('Brighton', 'GPE')],
#  [('Craig Bellamy', 'PERSON'), ('Cardiff City', 'GPE')],
#  [('Manchester City', 'GPE'), ('Liverpool', 'GPE'), ('Premier League', 'ORG')],
#  [('Premier League', 'ORG'), ('EFL', 'ORG')],
#  [('Newcastle', 'GPE'), ('Mike Ashley', 'PERSON')],
#  [('Ole Gunnar Solskjaer', 'PERSON'),
#   ('Man Utd', 'PERSON'),
#   ('Newcastle', 'GPE')],
#  [('Charlie Austin', 'PERSON'),
#   ('FA', 'ORG'),
#   ('Southampton', 'GPE'),
#   ('Man City', 'GPE')],
#  [('Ole Gunnar Solskjaer', 'PERSON'), ('Manchester United', 'ORG')],
#  [('Premier League', 'ORG'), ('Manchester City', 'GPE'), ('Liverpool', 'GPE')],
#  [('Groundhog Day', 'PERSON'),
#   ('Chelsea', 'PERSON'),
#   ('Maurizio Sarri', 'PERSON'),
#   ('Gonzalo Higuain', 'PERSON')],
#  [('BBC', 'ORG'),
#   ('Theresa May', 'PERSON'),
#   ('Derby', 'GPE'),
#   ('Southampton', 'GPE')],
#  [('Jose Mourinho', 'PERSON'), ('Manchester United', 'ORG')],
#  [('Chelsea', 'ORG')],
#  [('Andrew Robertson', 'PERSON'), ('Liverpool', 'GPE')],
#  [('Unai Emery', 'PERSON'), ('Arsenal', 'GPE'), ('Chelsea', 'PERSON')],
#  [('Manchester United', 'ORG'),
#   ('Europe', 'LOC'),
#   ('Premier League', 'ORG'),
#   ('Uefa', 'ORG')],
#  [('Marco Silva', 'PERSON'), ('Jordan Pickford', 'PERSON')],
#  [('the World Cup', 'EVENT'),
#   ('Chelsea', 'PERSON'),
#   ('Maurizio Sarri', 'PERSON')],
#  [('Claude Puel', 'PERSON'), ('Leicester', 'GPE')],
#  [('Marco Silva', 'PERSON'), ('Everton', 'PERSON')],
#  [('Brighton', 'GPE'), ('Liverpool', 'GPE'), ('Premier League', 'ORG')],
#  [('Premier League', 'ORG'),
#   ('Liverpool', 'GPE'),
#   ('Chelsea', 'PERSON'),
#   ('Newcastle', 'GPE')],
#  [('Gunnar Solskjaer', 'PERSON'), ('Man Utd', 'PERSON')],
#  [('Nikola Vlasic', 'PERSON'),
#   ('Everton', 'PERSON'),
#   ('Sam Allardyce', 'PERSON'),
#   ('Goodison', 'PERSON')],
#  [('Unai Emery', 'PERSON'), ('Arsenal', 'ORG')],
#  [('Premier League', 'ORG'), ('Tim Davie', 'PERSON')],
#  [('Fulham', 'GPE'),
#   ('Liverpool', 'GPE'),
#   ('Ryan Babel', 'PERSON'),
#   ('Besiktas', 'GPE')],
#  [('Chelsea', 'ORG'), ('Gonzalo Higuain', 'PERSON')],
#  [('Harry Kane', 'PERSON'), ('Tottenham', 'GPE')],
#  [('Richard Keogh', 'PERSON'),
#   ('Derby', 'GPE'),
#   ('Southampton', 'GPE'),
#   ('FA Cup', 'EVENT')],
#  [('Callum Hudson-Odoi', 'PERSON'),
#   ('Chelsea', 'PERSON'),
#   ('Bayern Munich', 'GPE')],
#  [('Chelsea', 'ORG'), ('Gonzalo Higuain', 'PERSON'), ('Juventus', 'ORG')],
#  [('Premier League', 'ORG')],
#  [],
#  [('Sven Mislintat', 'PERSON')],
#  [('David Wagner', 'PERSON'), ('Huddersfield Town', 'ORG')],
#  [('Newcastle', 'GPE'), ('Blackburn', 'GPE'), ('FA Cup', 'EVENT')],
#  [('Sven Mislintat', 'PERSON')],
#  [('Marcos Rojo', 'PERSON'), ('Manchester United', 'ORG')],
#  [('Man Utd', 'PERSON'),
#   ('Ole Gunnar Solskjaer', 'PERSON'),
#   ('Paul Pogba', 'PERSON')],
#  [('Sheffield', 'GPE'), ('Luton Town', 'ORG'), ('Chelsea', 'PERSON')],
#  [('Shrewsbury', 'GPE'), ('Stoke', 'GPE')],
#  [('Crystal Palace', 'FAC'),
#   ('Wayne Hennessey', 'PERSON'),
#   ('FA', 'ORG'),
#   ('Nazi', 'NORP')],
#  [('Aboubakar Kamara', 'PERSON'), ('Fulham', 'GPE')],
#  [('PSG', 'ORG'),
#   ('Chelsea', 'PERSON'),
#   ('349m', 'MONEY'),
#   ('Leandro Paredes', 'PERSON')],
#  [],
#  [('Darren Currie', 'PERSON'), ('Barnet', 'ORG')],
#  [('Premier League', 'ORG')],
#  [('Newcastle', 'GPE'), ('Rafa Benitez', 'PERSON')],
#  [('Premier League', 'ORG'),
#   ('Man City', 'GPE'),
#   ('Chelsea', 'PERSON'),
#   ('China', 'GPE'),
#   ('Man Utd', 'PERSON')],
#  [('Katrien', 'PERSON'), ('Meire', 'GPE'), ('Charlton', 'PERSON')],
#  [('Premier League', 'ORG')],
#  [('Notts County', 'GPE'), ('Alan Hardy', 'PERSON'), ('League Two', 'ORG')],
#  [('Eden Hazard', 'ORG'), ('Chelsea', 'ORG'), ('Gonzalo Higuain', 'PERSON')],
#  [('Alex Bruce', 'PERSON'),
#   ('Steve', 'PERSON'),
#   ('BBC', 'ORG'),
#   ('Sheffield', 'GPE')],
#  [('Mauricio Pochettino', 'PERSON'), ('Tottenham League Cup', 'ORG')],
#  [('Neymar', 'ORG'),
#   ('Manchester United Champions League', 'ORG'),
#   ('Thomas Tuchel', 'PERSON')],
#  [('Chelsea', 'PERSON')],
#  [('Chelsea', 'ORG'), ('Tottenham', 'GPE'), ('League Cup', 'EVENT')],
#  [('Chelsea', 'PERSON')],
#  [('Fulham', 'GPE')],
#  [('Neymar', 'ORG'),
#   ('Champions League', 'ORG'),
#   ('Manchester United', 'ORG')],
#  [('Ole Gunnar Solskjaer', 'PERSON'),
#   ('Man Utd', 'ORG'),
#   ('Burnley', 'PERSON')],
#  [('Chelsea', 'ORG'), ('Ross Barkley', 'PERSON')],
#  [('Miguel Almiron', 'PERSON'), ('Newcastle', 'GPE')],
#  [('Chelsea', 'ORG'),
#   ('Bayern Munich', 'GPE'),
#   ('Callum Hudson-Odoi', 'PERSON')],
#  [('Ole Gunnar Solskjaer', 'PERSON'), ('Manchester United', 'ORG')],
#  [('Scotland Yard', 'ORG'), ('Millwall for', 'ORG'), ('FA Cup', 'EVENT')],
#  [('Gonzalo Higuain', 'PERSON'),
#   ('Chelsea', 'PERSON'),
#   ('Premier League', 'ORG')],
#  [('Newcastle', 'GPE'),
#   ('Andreas Samaris', 'LOC'),
#   ('Antonio Barreca', 'ORG')],
#  [('Chelsea', 'PERSON'), ('Manchester United', 'GPE')],
#  [('Guardiola', 'PERSON'),
#   ('Manchester City', 'GPE'),
#   ('Premier League', 'ORG'),
#   ('Liverpool', 'GPE')],
#  [('Barnet', 'ORG'), ('FA Cup', 'ORG'), ('Brentford', 'GPE')],
#  [('Marco Silva', 'PERSON'), ('Everton', 'PERSON')],
#  [('Rafael Benitez', 'PERSON'), ('Newcastle', 'GPE')],
#  [('West Ham', 'PERSON'), ('the Premier League', 'ORG')],
#  [('Premier League', 'ORG'),
#   ('Manchester United', 'ORG'),
#   ('Manchester City', 'GPE')],
#  [('Man City', 'GPE'),
#   ('1129m', 'MONEY'),
#   ('Schalke for Rabbi Matondo', 'ORG'),
#   ('British', 'NORP')],
#  [('Everton', 'ORG'),
#   ('PSG', 'ORG'),
#   ('215m', 'MONEY'),
#   ('Idrissa Gueye', 'PERSON')],
#  [('Manchester City', 'GPE'), ('Burton', 'PERSON'), ('League Cup', 'EVENT')],
#  [('Brighton', 'GPE'), ('Liverpool', 'GPE'), ('Premier League', 'ORG')],
#  [('Southend United', 'ORG'), ('HM Revenue', 'ORG'), ('Customs', 'ORG')],
#  [('Harry Kane', 'PERSON'), ('Chelsea', 'PERSON')],
#  [('Liverpool', 'GPE')],
#  [],
#  [('Leeds', 'GPE'),
#   ('Norwich', 'GPE'),
#   ('West Brom', 'GPE'),
#   ('Derby', 'GPE')],
#  [('Aaron Ramsey', 'PERSON'), ('Juventus', 'ORG'), ('36m', 'MONEY')],
#  [('Gabriel Jesus', 'PERSON'), ('Sergio Aguero', 'PERSON')],
#  [('Martin ONeill', 'PERSON'), ('Nottingham Forest', 'ORG')],
#  [('Harry Kane', 'PERSON'), ('Tottenham', 'GPE')],
#  [('FA', 'ORG')],
#  [('Manchester City', 'GPE'), ('Jesus', 'PERSON'), ('Liverpool', 'GPE')],
#  [('Gunnar Solskjaer', 'ORG'), ('Marcus Rashford', 'PERSON')],
#  [('Red Bull', 'ORG'),
#   ('Paul Mitchell', 'PERSON'),
#   ('Manchester United', 'ORG')],
#  [('Conor Coady', 'PERSON'),
#   ('Wolves', 'ORG'),
#   ('Gareth Southgate', 'PERSON'),
#   ('England', 'GPE')],
#  [('David De Gea', 'PERSON'),
#   ('Tottenham', 'GPE'),
#   ('Ole Gunnar Solskjaer', 'PERSON'),
#   ('Man Utd', 'ORG'),
#   ('Pochettino', 'PERSON')],
#  [('Willy Boly', 'PERSON'), ('Bernardo Silva', 'PERSON')],
#  [('FA Cup', 'EVENT')],
#  [('Semitic', 'NORP'),
#   ('Carabao Cup', 'EVENT'),
#   ('Tottenham', 'GPE'),
#   ('Chelsea', 'PERSON')],
#  [('Premier League', 'ORG'), ('the FA Cup', 'EVENT')],
#  [],
#  [('Wayne Hennessey', 'PERSON'),
#   ('Nazi', 'NORP'),
#   ('Crystal Palace FA Cup', 'EVENT')],
#  [('Shelley Kerr', 'PERSON'),
#   ('Scotland', 'GPE'),
#   ('Women World Cup', 'EVENT')],
#  [('Martin Tyler', 'PERSON'), ('Woking', 'GPE'), ('Alex Ferguson', 'PERSON')],
#  [('Bernardo Silva - part', 'PERSON'), ('Man City', 'GPE')],
#  [('PFA', 'ORG'), ('Gordon Taylor', 'PERSON'), ('22m', 'MONEY')],
#  [('Paul Pogba', 'PERSON'), ('Manchester United', 'ORG'), ('FA Cup', 'EVENT')],
#  [('Manchester United', 'ORG'), ('Eric Bailly', 'PERSON')],
#  [('Manchester City', 'GPE')],
#  [('Liverpool', 'GPE'), ('Etihad', 'ORG')],
#  [('Mauricio Pochettino', 'PERSON'),
#   ('the Premier League or Champions League', 'ORG'),
#   ('the FA Cup', 'EVENT')],
#  [('Tranmere', 'ORG'),
#   ('Steven McNulty', 'PERSON'),
#   ('FA Cup', 'EVENT'),
#   ('Harry Kane', 'PERSON')],
#  [('Unai Emery', 'PERSON')],
#  [('Chelsea', 'ORG'),
#   ('Borussia Dortmund', 'ORG'),
#   ('Christian Pulisic', 'PERSON'),
#   ('576m', 'MONEY')],
#  [('Christian Eriksen', 'PERSON'),
#   ('Tottenham', 'GPE'),
#   ('New Year', 'EVENT')],
#  [('Premier League', 'ORG'), ('Manchester United', 'ORG'), ('Chelsea', 'ORG')],
#  [('Jamie Vardy', 'PERSON'),
#   ('Everton', 'PERSON'),
#   ('Claude Puel', 'PERSON'),
#   ('Leicester', 'GPE')],
#  [('Premier League', 'ORG'), ('BBC', 'ORG'), ('Tim Davie', 'PERSON')],
#  [('Bolton', 'PERSON')],
#  [('Cardiff', 'GPE'),
#   ('Neil Warnock', 'PERSON'),
#   ('Premier League', 'ORG'),
#   ('Tottenham', 'PERSON'),
#   ('Wembley', 'GPE')],
#  [('Newport', 'ORG'),
#   ('Padraig Amond', 'PERSON'),
#   ('Leicester', 'GPE'),
#   ('FA Cup', 'EVENT')],
#  [('Woking', 'ORG'), ('Watford', 'ORG')],
#  [('Dele Alli', 'PERSON'), ('Spurs', 'ORG')],
#  [('Bristol City', 'GPE'), ('Huddersfield', 'GPE'), ('the FA Cup', 'EVENT')],
#  [('Franck Ribery', 'PERSON'), ('Bayern Munich', 'GPE')],
#  [('Tottenham', 'PERSON'), ('Chelsea', 'PERSON')],
#  [('Tottenham', 'PERSON'), ('Chelsea', 'PERSON'), ('Carabao Cup', 'EVENT')],
#  [('the Premier League', 'ORG')],
#  [('Paul Pogba', 'PERSON'),
#   ('Jose Mourinho', 'PERSON'),
#   ('Man Utd', 'PERSON')],
#  [('Cesc Fabregas', 'PERSON'), ('Monaco', 'GPE'), ('Chelsea', 'PERSON')],
#  [('Jurgen Klopp', 'PERSON'),
#   ('Liverpool', 'GPE'),
#   ('Dejan Lovren', 'PERSON')],
#  [('Ruben Neves', 'PERSON'),
#   ('Jurgen Klopp', 'PERSON'),
#   ('Liverpool', 'GPE'),
#   ('FA Cup', 'EVENT')],
#  [('Maurizio Sarri', 'PERSON'),
#   ('Callum Hudson-Odoi', 'PERSON'),
#   ('Pedro', 'PERSON'),
#   ('Willian', 'PERSON'),
#   ('Chelsea', 'ORG')],
#  [('Man Utd', 'PERSON'),
#   ('Palace', 'ORG'),
#   ('Tottenham', 'GPE'),
#   ('Barnet', 'GPE'),
#   ('Brentford', 'GPE')],
#  [('Brighton', 'ORG'), ('Chris Hughton', 'PERSON')],
#  [('Samir Nasri', 'PERSON'), ('West Ham', 'ORG')],
#  [('Gunnar Solskjaer', 'PERSON'),
#   ('Alexis Sanchez', 'PERSON'),
#   ('Manchester United', 'ORG')],
#  [('Toby Alderweireld', 'PERSON'), ('PSG', 'ORG')],
#  [('Jurgen Klopp', 'PRODUCT'), ('Mohamed Salah', 'PERSON')],
#  [('Bournemouth', 'GPE')],
#  [('Declan Rice', 'PERSON'),
#   ('West Ham', 'ORG'),
#   ('Arsenal', 'ORG'),
#   ('Premier League', 'ORG')],
#  [('Ole Gunnar Solskjaer', 'PERSON'),
#   ('Tottenham', 'PERSON'),
#   ('Manchester United', 'ORG')],
#  [('Mohamed Salah', 'PERSON'), ('Liverpool', 'GPE'), ('Man City', 'GPE')],
#  [('Shane Long', 'PERSON'),
#   ('Southampton', 'GPE'),
#   ('Leicester City', 'GPE'),
#   ('Claude Puel', 'PERSON')],
#  [('Tottenham', 'GPE'),
# ...
#  [('Liverpool', 'GPE'),
#   ('Manchester United', 'ORG'),
#   ('Premier League', 'ORG')],
#  [('Patrick Bamford marks', 'PERSON'), ('Leeds', 'GPE'), ('Norwich', 'GPE')],
#  [('Nuno Espirito', 'PERSON'), ('Bournemouth', 'GPE')],
#  [('Premier League', 'ORG'),
#   ('Liverpool', 'GPE'),
#   ('Manchester United', 'GPE')],
#  [('Maurizio Sarri', 'PERSON'), ('NGolo Kante', 'ORG'), ('Chelsea', 'PERSON')],
#  [('Laurent Koscielny', 'PERSON'), ('Unai Emery', 'PERSON')],
#  [('Southampton', 'GPE'), ('Premier League', 'ORG')],
#  [('Jose Mourinho', 'PERSON'), ('Liverpool', 'GPE')],
#  [('Champions League', 'ORG'), ('English', 'NORP')],
#  [('Chelsea', 'ORG'), ('Spurs', 'LOC')],
#  [('Premier League', 'ORG')],
#  [('Charity Commission', 'ORG')],
#  [('Wolverhampton Wanderers', 'PERSON'),
#   ('Liverpool', 'GPE'),
#   ('Premier League', 'ORG')],
#  [('Premier League', 'ORG'), ('Liverpool', 'GPE')],
#  [('Arsenal', 'ORG'),
#   ('Peter Hill-Wood', 'PERSON'),
#   ('Arsene Wenger', 'PERSON')],
#  [('Unai Emery', 'PERSON'),
#   ('Liverpool', 'GPE'),
#   ('Invincibles', 'PERSON'),
#   ('Dejan Lovren', 'PERSON')],
#  [('Dominic Calvert-Lewin', 'PERSON'),
#   ('Everton', 'PERSON'),
#   ('Marco Silva', 'PERSON')],
#  [('Paul Pogba', 'PERSON'),
#   ('Ed Woodward', 'PERSON'),
#   ('Manchester United', 'ORG')],
#  [('Brighton', 'GPE')],
#  [('Claude Puel', 'PERSON'),
#   ('Leicester', 'GPE'),
#   ('Chelsea', 'PERSON'),
#   ('Manchester City', 'GPE')],
#  [('Manchester City', 'GPE')],
#  [('Eden Hazard', 'ORG'), ('Chelsea', 'PERSON'), ('Real Madrid', 'ORG')],
#  [('West Ham', 'LOC'), ('Xavi Valero', 'PERSON')],
#  [('Chelsea', 'ORG'), ('Watford', 'ORG')],
#  [('Alexis Sanchez', 'PERSON'), ('Manchester United', 'GPE')],
#  [('Aitor Karanka', 'PERSON'),
#   ('Nottingham Forest', 'ORG'),
#   ('Championship', 'ORG')],
#  [('Manchester City', 'GPE'), ('Leicester', 'GPE')],
#  [('Paul Pogba', 'PERSON'),
#   ('Manchester United', 'ORG'),
#   ('Ole Gunnar Solskjaer', 'ORG'),
#   ('Huddersfield', 'GPE')],
#  [('Carlo Ancelotti', 'PERSON'),
#   ('Inter Milan', 'ORG'),
#   ('Napoli', 'GPE'),
#   ('Kalidou Koulibaly', 'PERSON')],
#  [('Bernardo Silva', 'PERSON'),
#   ('Manchester City', 'GPE'),
#   ('Premier League', 'ORG')],
#  [('Tottenham', 'GPE'), ('Bournemouth', 'GPE')],
#  [('Everton', 'ORG'), ('Burnley', 'PERSON'), ('Sean Dyche', 'PERSON')],
#  [('Liverpool', 'GPE'), ('Newcastle', 'GPE'), ('Premier League', 'ORG')],
#  [('Maurizio Sarri', 'PERSON'), ('Semitic', 'NORP'), ('Chelsea', 'PERSON')],
#  [('Manchester United', 'GPE'),
#   ('Huddersfield', 'GPE'),
#   ('Premier League', 'ORG')],
#  [('Premier League', 'ORG'),
#   ('Liverpool', 'GPE'),
#   ('Manchester United', 'GPE'),
#   ('Arsenal', 'ORG'),
#   ('Chelsea', 'ORG'),
#   ('Tottenham', 'GPE'),
#   ('Man City', 'GPE')],
#  [('Rafael Benitez', 'PERSON'), ('Newcastle', 'GPE'), ('Liverpool', 'GPE')],
#  [('Brendan Rodgers', 'PERSON'), ('Celtic', 'NORP')],
#  [('Marco Silva', 'PERSON'),
#   ('Everton', 'PERSON'),
#   ('Jordan Pickford', 'PERSON')],
#  [('Unai Emery', 'PERSON'),
#   ('100 per cent', 'MONEY'),
#   ('Lucas Torreira', 'PERSON'),
#   ('Liverpool', 'GPE')],
#  [('Manchester City', 'GPE')],
#  [('Jurgen Klopp', 'PERSON'), ('Liverpool', 'GPE')],
#  [('Liverpool', 'GPE'), ('Newcastle', 'GPE'), ('Premier League', 'ORG')],
#  [('Brighton vs Arsenal', 'ORG'), ('Premier League', 'ORG')],
#  [('Steve Holland', 'PERSON'),
#   ('Premier League', 'ORG'),
#   ('England', 'GPE'),
#   ('World Cup', 'EVENT')],
#  [('Alvaro Morata', 'PERSON'),
#   ('Chelsea', 'PERSON'),
#   ('Maurizio Sarri', 'PERSON'),
#   ('Eden Hazard', 'PERSON')],
#  [('Jurgen Locadia', 'PERSON'), ('Brighton', 'GPE'), ('Everton', 'ORG')],
#  [('Wolves give Spurs', 'ORG')],
#  [('Aleksandar Mitrovic', 'PERSON'),
#   ('Fulham', 'GPE'),
#   ('Aboubakar Kamara', 'PERSON'),
#   ('Huddersfield', 'PERSON')],
#  [('Ole Gunnar Solskjaer', 'PERSON'),
#   ('Anthony Martial', 'PERSON'),
#   ('David de Gea', 'PERSON'),
#   ('Man Utd', 'PERSON')],
#  [('Newcastle', 'GPE'), ('Abdoulaye Doucoure', 'ORG'), ('Watford', 'ORG')],
#  [('Jurgen Klopp', 'PERSON'),
#   ('Raheem Sterling', 'PERSON'),
#   ('Stamford Bridge', 'FAC')],
#  [('League World Cup', 'EVENT')],
#  [('Fran Alonso', 'PERSON'),
#   ('Super League', 'ORG'),
#   ('Premier League', 'ORG'),
#   ('Lewes', 'ORG')],
#  [('Chelsea', 'ORG'), ('Raheem Sterling', 'PERSON')],
#  [('Jose Mourinho', 'PERSON'), ('Jurgen Klopp', 'PERSON')],
#  [('Cesc Fabregas', 'PERSON'), ('Chelsea', 'PERSON')],
#  [('Premier League', 'ORG'), ('Liverpool', 'GPE')],
#  [('David Pleat', 'PERSON'), ('FA Cup', 'EVENT')],
#  [('Unai Emery', 'PERSON')],
#  [('Felipe Anderson', 'PERSON'), ('West Ham', 'ORG'), ('Southampton', 'GPE')],
#  [('Liverpool', 'GPE'), ('Premier League', 'ORG')],
#  [('France', 'GPE'),
#   ('the World Cup', 'EVENT'),
#   ('England', 'GPE'),
#   ('Jose Mourinho', 'PERSON'),
#   ('Man Utd', 'PERSON')],
#  [],
#  [('Paul Pogba', 'PERSON'), ('Manchester United', 'ORG')],
#  [('Chelsea', 'ORG'),
#   ('NGolo Kante', 'ORG'),
#   ('David Luiz', 'PERSON'),
#   ('Manchester City', 'GPE')],
#  [('West Ham', 'PERSON'),
#   ('Roy Hodgson', 'PERSON'),
#   ('Crystal Palace', 'FAC')],
#  [('Phil Foden', 'PERSON'), ('Manchester City', 'GPE')],
#  [('CopaLibertadores', 'ORG'),
#   ('Stunning', 'ORG'),
#   ('Juan Quintero', 'PERSON'),
#   ('River Plate', 'ORG'),
#   ('Boca Juniors', 'ORG')],
#  [('Lucas Torreira', 'PERSON'), ('Huddersfield', 'GPE')],
#  [('Joe Gomez', 'PERSON'), ('Liverpool', 'GPE')],
#  [('John Barnes', 'PERSON'), ('Raheem Sterling', 'PERSON')],
#  [('Liverpool', 'GPE'),
#   ('Manchester United', 'ORG'),
#   ('Premier League', 'ORG')],
#  [('Premier League', 'ORG'),
#   ('Everton', 'PERSON'),
#   ('Manchester City', 'GPE')],
#  [('Jurgen Klopp', 'PERSON'), ('Liverpool', 'GPE')],
#  [('Champions League', 'ORG'), ('English', 'LANGUAGE')],
#  [('Laurent Koscielny', 'PERSON')],
#  [('the Premier League', 'ORG'),
#   ('Crystal Palace', 'FAC'),
#   ('Roy Hodgson', 'PERSON')],
#  [('Bournemouth', 'GPE'), ('England', 'GPE'), ('Lewis Cook', 'PERSON')],
#  [('Manchester United', 'ORG'), ('Fulham', 'GPE'), ('Premier League', 'ORG')],
#  [('England', 'GPE'), ('Jordan Nobbs', 'PERSON'), ('World Cup', 'EVENT')],
#  [('Manchester City', 'GPE'),
#   ('7m', 'MONEY'),
#   ('USA', 'GPE'),
#   ('Zack Steffen', 'PERSON')],
#  [('Jose Mourinho', 'PERSON'),
#   ('Fred', 'PERSON'),
#   ('Manchester United', 'ORG')],
#  [('Rob Holding', 'PERSON')],
#  [('Danny Graham', 'PERSON'),
#   ('Blackburn', 'PERSON'),
#   ('Premier League', 'ORG')],
#  [('Manchester United', 'ORG')],
#  [('Manchester United', 'GPE'), ('Huddersfield', 'GPE')],
#  [('Mauricio Pochettino', 'PERSON')],
#  [('Henrikh Mkhitaryan', 'PERSON')],
#  [('Leeds', 'GPE'), ('United', 'ORG')],
#  [],
#  [('Brighton vs Arsenal', 'ORG')],
#  [('Liverpool', 'GPE'), ('Newcastle', 'GPE')],
#  [('Champions League', 'ORG'),
#   ('Liverpool', 'GPE'),
#   ('Tottenham', 'GPE'),
#   ('Napoli', 'GPE'),
#   ('Barcelona', 'GPE')],
#  [('Liverpool', 'GPE'), ('Napoli', 'GPE'), ('Champions League', 'ORG')],
#  [('Barcelona', 'GPE'), ('the Nou Camp', 'FAC')],
#  [],
#  [('Marco Silva', 'PERSON'),
#   ('Everton', 'PERSON'),
#   ('Watford', 'ORG'),
#   ('Lucas Digne', 'PERSON')],
#  [('Football Supporters Federation', 'ORG')],
#  [('Barcelona', 'GPE'),
#   ('Champions League', 'ORG'),
#   ('Lionel Messi', 'PERSON'),
#   ('Spurs', 'ORG')],
#  [('Everton', 'ORG'),
#   ('Marco Silva', 'PERSON'),
#   ('Richarlison', 'PERSON'),
#   ('Watford', 'ORG')],
#  [('Barcelona', 'GPE'), ('Tottenham Champions League', 'ORG')],
#  [('Champions League', 'ORG'), ('Liverpool', 'GPE'), ('Tottenham', 'GPE')],
#  [('Sergio Aguero', 'PERSON'),
#   ('Manchester City', 'GPE'),
#   ('Stamford Bridge', 'FAC')],
#  [('Maurizio Sarri', 'PERSON'),
#   ('Eden Hazard', 'FAC'),
#   ('Chelsea', 'PERSON'),
#   ('Carabao Cup', 'EVENT')],
#  [('Ole Gunnar Solskjaer', 'PERSON'), ('Manchester United', 'GPE')],
#  [('Claude Puel', 'PERSON'),
#   ('Jamie Vardy', 'PERSON'),
#   ('Carabao Cup', 'EVENT'),
#   ('Man City', 'GPE'),
#   ('Premier League', 'ORG')],
#  [('Charlie Austin', 'PERSON'), ('Southampton', 'GPE')],
#  [('Burton', 'PERSON'),
#   ('Liam Boyce', 'PERSON'),
#   ('Bundesliga', 'EVENT'),
#   ('Belfast', 'GPE')],
#  [('Unai Emery', 'PERSON')],
#  [('Mason Greenwood', 'ORG'),
#   ('Man Utd', 'PERSON'),
#   ('Chelsea', 'PERSON'),
#   ('FA Youth Cup', 'ORG')],
#  [('Jose Mourinho', 'PERSON'), ('Manchester United', 'ORG')],
#  [('Tottenham', 'GPE'), ('London', 'GPE')],
#  [('Jurgen Klopp', 'PERSON'), ('Liverpool', 'GPE')],
#  [('Jose Mourinho', 'PERSON'), ('Manchester United', 'ORG')],
#  [('the Premier League', 'ORG')],
#  [('Cesar Azpilicueta', 'PERSON'), ('Chelsea', 'PERSON')],
#  [],
#  [('Uefa', 'ORG'), ('Pierre-Emerick Aubameyang', 'PERSON')],
#  [('Premier League', 'ORG'),
#   ('Gabriel Jesus', 'PERSON'),
#   ('Manchester City', 'GPE')],
#  [('Tottenham', 'GPE'), ('Premier League', 'ORG'), ('London', 'GPE')],
#  [('Jose Mourinho', 'PERSON'), ('Man Utd', 'PERSON'), ('Southampton', 'GPE')],
#  [('England', 'GPE'),
#   ('Czech Republic', 'GPE'),
#   ('Northern Ireland', 'GPE'),
#   ('Germany', 'GPE'),
#   ('Holland', 'GPE')],
#  [('Manchester City', 'GPE'), ('Bournemouth', 'PERSON')],
#  [('Cesar Azpilicueta', 'PERSON'), ('Chelsea', 'ORG')],
#  [('David Moyes', 'PERSON'),
#   ('Everton', 'PERSON'),
#   ('Anfield', 'PERSON'),
#   ('Liverpool', 'GPE')],
#  [('Unai Emery', 'PERSON'),
#   ('Tottenham', 'GPE'),
#   ('Mauricio Pochettino', 'PERSON'),
#   ('Pep Guardiola', 'PERSON'),
#   ('Diego Simeone', 'GPE')],
#  [('West Ham', 'ORG'), ('Newcastle United', 'GPE'), ('St James Park', 'GPE')],
#  [],
#  [('Liverpool', 'GPE'),
#   ('Everton', 'PERSON'),
#   ('Premier League', 'ORG'),
#   ('Merseyside', 'GPE')],
#  [('Premier League', 'ORG'), ('Everton', 'PERSON'), ('Liverpool', 'GPE')],
#  [('Slough', 'LOC'), ('FA Cup', 'EVENT')],
#  [('Chelsea', 'PERSON'), ('Fulham', 'GPE'), ('Premier League', 'ORG')],
#  [('Will Manchester City', 'PERSON'), ('the Premier League', 'ORG')],
#  [('Jordan Pickford', 'PERSON'), ('Everton', 'PERSON')],
#  [('Wilfried Zaha', 'PERSON'), ('Crystal Palace', 'ORG')],
#  [('Diogo Dalot', 'PERSON'), ('Man Utd', 'PERSON')],
#  [('Chelsea', 'ORG'), ('Man City', 'GPE'), ('Morgan Gibbs-White', 'PERSON')],
#  [('Liverpool', 'GPE'), ('Burnley', 'PERSON')],
#  [('David de Gea', 'PERSON'),
#   ('Eden Hazard', 'GPE'),
#   ('Aaron Ramsey', 'PERSON')],
#  [('Leicester', 'GPE'), ('Fulham', 'GPE'), ('Claudio Ranieri', 'PERSON')],
#  [('Danny Rose', 'PERSON'),
#   ('Wembley', 'GPE'),
#   ('Tottenham', 'GPE'),
#   ('Southampton', 'GPE')],
#  [],
#  [('Guardiola', 'PERSON'), ('Chelsea', 'PERSON'), ('Manchester City', 'GPE')],
#  [('Bournemouth', 'GPE'), ('Liverpool', 'GPE'), ('Premier League', 'ORG')],
#  [('Manchester City', 'GPE'), ('Jose Mourinho', 'PERSON')],
#  [('Chelsea', 'PERSON'), ('Manchester City', 'GPE')],
#  [('Chelsea', 'PERSON'), ('Manchester City', 'GPE')],
#  [('Leicester', 'GPE'), ('Tottenham', 'GPE'), ('Premier League', 'ORG')],
#  [('Jose Mourinho', 'PERSON')],
#  [('Liverpool', 'GPE')],
#  [('Chelsea', 'PERSON')],
#  [('Jay Rodriguez', 'PERSON'),
#   ('West Brom', 'GPE'),
#   ('Aston Villa', 'PERSON')],
#  [('Leicester', 'GPE'), ('Tottenham', 'GPE'), ('Premier League', 'ORG')],
#  [('Harry Kane', 'PERSON'),
#   ('Alexandre Lacazette', 'PERSON'),
#   ('Pierre-Emerick Aubameyang', 'PERSON'),
#   ('London', 'GPE')],
#  [('Tottenham', 'GPE'), ('Premier League', 'ORG'), ('London', 'GPE')],
#  [('Southampton', 'GPE'), ('Man Utd', 'PERSON'), ('Premier League', 'ORG')],
#  [('England', 'GPE')],
#  [('Premier League', 'ORG'),
#   ('Manchester Utd', 'ORG'),
#   ('Southampton', 'GPE')],
#  [('Tim Flowers', 'PERSON'), ('Solihull', 'ORG'), ('Blackpool', 'GPE')],
#  [('Tottenham', 'GPE'), ('Premier League', 'ORG'), ('London', 'GPE')],
#  [('Jurgen Klopp', 'PERSON'),
#   ('Marco Silva', 'PERSON'),
#   ('Everton', 'PERSON'),
#   ('Merseyside', 'GPE')],
#  [('Chelsea', 'PERSON'), ('Fulham', 'GPE'), ('Premier League', 'ORG')],
#  [('Michael Keane', 'PERSON')],
#  [('England', 'GPE')],
#  [('the Premier League', 'ORG')],
#  [('Celtic', 'NORP'), ('Leigh Griffiths', 'PERSON')],
#  [('Champions League', 'ORG')],
#  [('Fulham', 'GPE'),
#   ('Islam Slimani', 'PERSON'),
#   ('Claudio Ranieri', 'PERSON')],
#  [('Manchester City', 'GPE'),
#   ('Pep Guardiola', 'PERSON'),
#   ('diamond Phil Foden', 'PERSON')],
#  [('Martin Glenn', 'PERSON'), ('FA', 'ORG'), ('Wembley', 'GPE')],
#  [('Arsenal', 'ORG'), ('Ainsley Maitland-Niles', 'ORG')],
#  [('Ralph Hasenhuttl', 'PERSON'), ('Southampton', 'GPE')],
#  [('Manchester City', 'GPE'), ('Champions League', 'ORG')],
#  [('Sol Campbell', 'PERSON'), ('Macclesfield', 'GPE')],
#  [('Chris Hughton', 'PERSON'), ('Brighton', 'GPE'), ('Crystal Palace', 'FAC')],
#  [('Bradford', 'PERSON'), ('Edin Rahic', 'PERSON')],
#  [('Premier League', 'ORG'), ('Manchester United', 'GPE')],
#  [('Gareth Southgate', 'PERSON'),
#   ('English', 'NORP'),
#   ('Premier League', 'ORG')],
#  [('Sheffield', 'GPE'), ('Manchester City', 'GPE')],
#  [('Manchester United vs Arsenal', 'ORG')],
#  [('Rafael Benitez', 'PERSON'), ('Newcastle', 'GPE')],
#  [('Mohamed Salah', 'PERSON'), ('Liverpool', 'GPE'), ('Bournemouth', 'GPE')],
#  [('James Tarkowski', 'PERSON'),
#   ('Burnley', 'PERSON'),
#   ('Brighton  Hove Albion', 'ORG')],
#  [('Son Heung-min', 'PERSON'), ('Tottenham', 'PERSON'), ('Leicester', 'GPE')],
#  [('Manchester United', 'ORG'), ('Paul Pogba', 'PERSON'), ('Fulham', 'GPE')],
#  [('Cardiff City', 'GPE'),
#   ('Callum Paterson', 'PERSON'),
#   ('Ralph Hasenhuttl', 'PERSON'),
#   ('Southampton', 'GPE')],
#  [('Raheem Sterling', 'PERSON'),
#   ('Chelsea', 'PERSON'),
#   ('Stamford Bridge', 'FAC')],
#  [('Raheem Sterling', 'PERSON'), ('Stamford Bridge', 'FAC')],
#  [('Marco Silva', 'PERSON'), ('Richarlison', 'PERSON'), ('Watford', 'ORG')],
#  [],
#  [('Jose Mourinho', 'PERSON'),
#   ('Man Utd', 'PERSON'),
#   ('Spurs', 'ORG'),
#   ('Mauricio Pochettino', 'PERSON')],
#  [('Danny Rose', 'PERSON')],
#  [('Man Utd', 'PERSON'), ('Mauricio Pochettino', 'PERSON'), ('Spurs', 'ORG')],
#  [('Dele Alli', 'PERSON'), ('Spurs', 'ORG'), ('Carabao Cup', 'EVENT')],
#  [('Ole Gunnar Solskjaer', 'PERSON'),
#   ('Trafford', 'GPE'),
#   ('Man Utd', 'PERSON')],
#  [('Mauricio Pochettino', 'PERSON'),
#   ('Tottenham', 'PERSON'),
#   ('Man Utd', 'PERSON')],
#  [('Dele Alli', 'PERSON'), ('Tottenham', 'GPE'), ('Arsenal', 'PERSON')],
#  [('Manuel Pellegrini', 'PERSON'), ('West Ham', 'GPE')],
#  [('Ole Gunnar Solskjaer', 'PERSON'),
#   ('England', 'GPE'),
#   ('Manchester United', 'GPE')],
#  [('Norway', 'GPE'),
#   ('Ole Gunnar Solskjaer', 'PERSON'),
#   ('Manchester United', 'GPE')],
#  [('Telegraph', 'ORG'), ('Premier League', 'ORG')],
#  [],
#  [('NGolo Kante', 'ORG'), ('Chelsea', 'PERSON')],
#  [('Premier League', 'ORG'),
#   ('Chelsea', 'PERSON'),
#   ('Tottenham', 'GPE'),
#   ('London', 'GPE')],
#  [('Bournemouth vs Arsenal', 'GPE')],
#  [],
#  [('Sadio Mane', 'PERSON'), ('Liverpool', 'GPE')],
#  [('Jorginho', 'PERSON'), ('Chelsea', 'PERSON')],
#  [('VAR', 'ORG')],
#  [('Premier League', 'ORG'), ('FA', 'ORG')],
#  [('Manchester City', 'GPE'),
#   ('Fulham', 'GPE'),
#   ('Brahim Diaz', 'PERSON'),
#   ('Kevin De Bruyne', 'PERSON')],
#  [('Greek', 'NORP'), ('West Ham', 'ORG')],
#  [('Heung-min Son', 'PERSON'),
#   ('Tottenham', 'GPE'),
#   ('West Ham', 'LOC'),
#   ('Carabao Cup', 'EVENT')],
#  [('Michael Gove', 'PERSON'), ('Telegraph', 'ORG'), ('Premier League', 'ORG')],
#  [('PFA', 'ORG')],
#  [('Forest Green Rovers', 'ORG')],
#  [('Emirates', 'GPE'),
#   ('Guiseley', 'ORG'),
#   ('Joey Barton', 'PERSON'),
#   ('Fleetwood Town', 'PRODUCT'),
#   ('Portsmouth', 'GPE'),
#   ('Rochdale', 'GPE')],
#  [('Gordon Taylor', 'PERSON'), ('PFA', 'ORG')],
#  [('Ireland', 'GPE'), ('Matt Doherty', 'PERSON'), ('Martin ONeill', 'PERSON')],
#  [('Unai Emery', 'PERSON')],
#  [('Oldham', 'GPE'), ('Hampton  Richmond', 'ORG')],
#  [('Charity Commission', 'ORG'),
#   ('Gordon Taylor', 'PERSON'),
#   ('229m', 'MONEY'),
#   ('PFA', 'ORG')],
#  [('Arsenal', 'PERSON'),
#   ('Unai Emery', 'PERSON'),
#   ('Arsene Wenger', 'PERSON')],
#  [('Blackpool', 'GPE'), ('Matteo Guendouzi', 'PERSON')],
#  [('Didier Drogba', 'PERSON'), ('Chelsea', 'PERSON'), ('God', 'PERSON')],
#  [('Wembley', 'GPE'), ('FA Cup', 'EVENT')],
#  [('Tottenham', 'PERSON'),
#   ('White Hart Lane', 'FAC'),
#   ('Wembley', 'GPE'),
#   ('Mauricio Pochettino', 'PERSON')],
#  [('Jose Mourinho', 'PERSON'),
#   ('Iker Casillas', 'PERSON'),
#   ('David de Gea', 'PERSON'),
#   ('Spain', 'GPE')],
#  [('Mauricio Pochettino', 'PERSON')],
#  [('Manchester United', 'ORG'), ('Crystal Palace', 'FAC')],
#  [('Manuel Pellegrini', 'PERSON'), ('Manchester City', 'GPE')],
#  ...]

# %%
title_entities[:2]
# Out:
# [[('Son Hueng-min', 'PERSON'), ('Tottenham', 'PERSON'), ('Spurs', 'ORG')],
#  [('Burnley', 'PERSON'), ('Sean Dyche', 'PERSON')]]

# %% [markdown]
# I think move to count the entities, and count things to try and normalise
#
# * Things like Tottenham and Spurs could be related to be together, to group
# * I think grouping things together might be a good way in general to normalise
# * Note that once we have normalised, we should run an extract / replace - so that we avoid errors in the tagger
# * Will have to shave off some things like 's
# * Also have slight issue in defining whether someone is a person or player or manager - maybe not super important for now
#     * This could be classified using context
#     * Or maybe defined, again, using a network
#
# To do:
#
# * See what the common entities are (considered as singles)
# * See what common "n gram" entities are (Tottenham Spurs)
# * See what connections we have

# %%
all_ents = []
_ = [all_ents.append(ent) for title_ents in title_entities for ent in title_ents]

# %%
all_ents[0:5]
# Out:
# [('Son Hueng-min', 'PERSON'),
#  ('Tottenham', 'PERSON'),
#  ('Spurs', 'ORG'),
#  ('Burnley', 'PERSON'),
#  ('Sean Dyche', 'PERSON')]

# %%
ent_frame = pd.DataFrame(all_ents, columns = ['entity', 'tag'])

# Remove if entity is empty
ent_frame = ent_frame[ent_frame.entity != ''].reset_index(drop = True)

# Get the count of the combination
ent_frame['combination_count'] = ent_frame.groupby(['entity', 'tag'])['tag'].transform('count')

# Get the count of the entity alone
ent_frame['entity_count'] = ent_frame.groupby('entity')['tag'].transform('count')

# And drop all duplicates
ent_frame = ent_frame.drop_duplicates().reset_index(drop = True)

# And get one with most popular
only_ents = ent_frame.sort_values('entity_count', ascending = False).drop_duplicates('entity').reset_index(drop = True)

# %% [markdown]
# Have to check some stuff:
#
# * How many only have 1
# * How many are above a certain count (i.e. quantiles)

# %%
prct_1 = (only_ents.entity_count == 1).mean()
print('{:.0%} have only a single count'.format(prct_1))
print(only_ents.loc[only_ents.entity_count != 1, 'entity_count'].quantile([0.25, 0.5, 0.75, 0.9]))
# Out:
# 60% have only a single count
# 0.25     2.0
# 0.50     4.0
# 0.75     9.0
# 0.90    25.0
# Name: entity_count, dtype: float64

# %% [markdown]
# Treatments:
#
# * Replace Man with manchester, utd with united
#
# The goal here is to try and get some stuff that we can use as a base set of "good tags", so that we can train our own tagger that only takes into account the stuff we are interested in
#
# * Don't know if need to create a new "train" set, where we have some stuff separated by spaces, or if we should just put everything as it is
# * Don't want to get into a thing where we just pick up key terms
#
# We need a well tagged set to relate tags between them to get "what" they are
#
# * Maybe need to do an exercise of scraping teams and construct a dictionary of replacements / nick names to get everything normalised
#     * Not super scalable, but the tags we are getting back here won't really work that well either
# * Need to find a source where we can scrape this stuff
# * I guess we could start with something relatively limited, and at least get the process down, so we can expand later
#
# https://en.wikipedia.org/wiki/List_of_association_football_competitions
#
# https://en.wikipedia.org/wiki/Premier_League
# https://en.wikipedia.org/wiki/Primeira_Liga
# https://en.wikipedia.org/wiki/Eredivisie
# https://en.wikipedia.org/wiki/EFL_Championship
# https://en.wikipedia.org/wiki/EFL_League_One
# https://en.wikipedia.org/wiki/EFL_League_Two
# https://en.wikipedia.org/wiki/La_Liga
# https://en.wikipedia.org/wiki/Segunda_Divisi%C3%B3n
# https://en.wikipedia.org/wiki/Bundesliga
# https://en.wikipedia.org/wiki/Serie_A
# https://en.wikipedia.org/wiki/Ligue_1

# %%
only_ents[only_ents.entity_count >= 25]
# Out:
#                         entity          tag  combination_count  entity_count
# 0                    Liverpool          GPE               1248          1249
# 1                      Chelsea      PRODUCT                  1          1092
# 2            Manchester United          ORG                806          1056
# 3              Manchester City          GPE                766           766
# 4               Premier League          ORG                652           652
# 5                    Tottenham          GPE                449           629
# 6                       Celtic          GPE                  2           406
# 7                    Barcelona          GPE                372           388
# 8                    Newcastle          GPE                382           382
# 9                      Everton          ORG                119           349
# 10                    West Ham          LOC                 59           341
# 11                 Southampton          GPE                308           308
# 12                   Leicester          GPE                307           307
# 13                      Fulham          GPE                250           300
# 14        Ole Gunnar Solskjaer          ORG                 19           292
# 15                     Watford       PERSON                 27           289
# 16                     Cardiff          GPE                264           264
# 17                     Burnley          GPE                  2           263
# 18                 Real Madrid          ORG                263           263
# 19              Crystal Palace          LOC                 14           262
# 20              Maurizio Sarri       PERSON                251           251
# 21            Champions League        EVENT                  7           238
# 22                 Bournemouth       PERSON                 85           238
# 23                     Rangers          ORG                211           236
# 24                Jurgen Klopp       PERSON                222           223
# 25               Jose Mourinho       PERSON                219           219
# 26                    Brighton          LOC                  2           215
# 27                      FA Cup          ORG                 12           208
# 28         Mauricio Pochettino       PERSON                200           200
# 29                         PSG          ORG                196           196
# 30                Huddersfield          GPE                 72           191
# 31                    Man City       PERSON                 13           190
# 32                     Arsenal          GPE                 39           187
# 33                     Man Utd          ORG                 45           186
# 34                     England         NORP                  1           185
# 35                    Juventus          ORG                179           179
# 36          the Premier League          ORG                167           167
# 37                  Unai Emery       PERSON                166           166
# 38                       Leeds          GPE                159           159
# 39                  Paul Pogba       PERSON                148           149
# 40               Bayern Munich       PERSON                 57           127
# 41                   Guardiola          GPE                  1           123
# 42               Europa League          ORG                121           122
# 43                      Europe          LOC                116           116
# 44               Pep Guardiola          LOC                  1           114
# 45             Brendan Rodgers       PERSON                110           110
# 46                       Spurs          LOC                  1           108
# 47                 Marco Silva       PERSON                107           107
# 48                      London          GPE                107           107
# 49                    Aberdeen          GPE                102           102
# 50              Leicester City          GPE                101           101
# 51                          FA          ORG                101           101
# 52                      Bolton       PERSON                100           100
# 53                     La Liga       PERSON                 48            95
# 54               Emiliano Sala       PERSON                 95            95
# 55                     Wembley          GPE                 95            95
# 56                  Man United          ORG                  9            94
# 57                       Derby          GPE                 83            92
# 58              Steven Gerrard       PERSON                 92            92
# 59                Jürgen Klopp       PERSON                 91            91
# 60                  Harry Kane       PERSON                 91            91
# 61                      United          ORG                 88            89
# 62             Raheem Sterling          ORG                  8            89
# 63                   Blackpool          GPE                 89            89
# 64               Mohamed Salah       PERSON                 88            88
# 65                Lionel Messi       PERSON                 88            88
# 66                   West Brom          GPE                 28            85
# 67          Callum Hudson-Odoi       PERSON                 85            85
# 68                      Napoli          GPE                 83            83
# 69                        Hibs          ORG                 56            82
# 70                  Sunderland          GPE                 17            80
# 71                       Stoke       PERSON                  7            80
# 72             Claudio Ranieri       PERSON                 80            80
# 73                    European         NORP                 79            79
# 74                Cardiff City          GPE                 78            78
# 75                    Scottish         NORP                 78            78
# 76                  Shrewsbury          GPE                 78            78
# 77                 Eden Hazard  WORK_OF_ART                  2            76
# 78             Marcus Rashford       PERSON                 76            76
# 79                 Carabao Cup       PERSON                  2            76
# 80                Rafa Benitez       PERSON                 76            76
# 81                  Manchester          GPE                 73            75
# 82                     Ipswich          GPE                 75            75
# 83                 Aston Villa          FAC                  3            74
# 84                     Swansea          LOC                  4            74
# 85                      Dundee          GPE                 73            73
# 86                Bristol City          GPE                 72            72
# 87                    Millwall       PERSON                 12            70
# 88                  Portsmouth          GPE                 70            70
# 89                    Valencia          GPE                 70            70
# 90                      Neymar          ORG                 19            70
# 91           Cristiano Ronaldo       PERSON                 69            69
# 92                     English     LANGUAGE                 27            68
# 93                     Norwich          GPE                 44            68
# 94                   Sheffield          GPE                 68            68
# 95                Neil Warnock       PERSON                 67            67
# 96                       Sarri       PERSON                 28            66
# 97             Football League          ORG                 65            65
# 98                  Kilmarnock          GPE                 64            64
# 99               Middlesbrough       PERSON                  2            64
# 100                      Klopp          GPE                 13            63
# 101               Macclesfield         NORP                  4            63
# 102                    Serie A          ORG                 63            63
# 103                   Dortmund          GPE                 63            63
# 104                     Madrid          GPE                 63            63
# 105                        QPR          ORG                 63            63
# 106                  LIVERPOOL          GPE                 63            63
# 107                    Wrexham       PERSON                  2            62
# 108                 Motherwell          ORG                 27            62
# 109                   Mourinho          ORG                  1            60
# 110                   Trafford          GPE                 58            60
# 111                    Newport          GPE                  6            60
# 112                   Solskjær          ORG                  7            59
# 113                      Luton          GPE                 20            59
# 114                 Mesut Ozil       PERSON                 59            59
# 115                     Monaco          ORG                  1            59
# 116          Borussia Dortmund          ORG                 50            58
# 117                      Paris          GPE                 58            58
# 118            Gonzalo Higuain       PERSON                 58            58
# 119                      Wigan       PERSON                 14            57
# 120               Notts County          GPE                 57            57
# 121  Pierre-Emerick Aubameyang       PERSON                 57            57
# 122                 MANCHESTER          GPE                 56            56
# 123                     LONDON          GPE                 56            56
# 124                       Roma          GPE                 56            56
# 125           Ralph Hasenhuttl       PERSON                 55            55
# 126                 Pochettino       PERSON                 53            55
# 127                   Rochdale          GPE                 54            54
# 128                Northampton          GPE                 54            54
# 129           Marko Arnautovic       PERSON                 54            54
# 130                      Villa          ORG                 54            54
# 131                  Brentford          ORG                  1            54
# 132                  Doncaster         NORP                 16            53
# 133               St Johnstone       PERSON                 49            53
# 134                 Sean Dyche       PERSON                 53            53
# 135              José Mourinho       PERSON                 51            51
# 136                        VAR          ORG                 51            51
# 137                       Sala       PERSON                 51            51
# 138                  St Mirren       PERSON                 46            51
# 139                     Yeovil          GPE                 43            50
# 140                  Blackburn       PERSON                 12            50
# 141          Manuel Pellegrini       PERSON                 50            50
# 142             Bristol Rovers          ORG                 49            49
# 143            Virgil van Dijk       PERSON                 49            49
# 144                 Birmingham          GPE                 49            49
# 145                       Lyon       PERSON                  5            49
# 146                    Swindon          GPE                 41            49
# 147                     Oldham       PERSON                  4            49
# 148                  Cambridge          GPE                 49            49
# 149              Coventry City          GPE                 48            48
# 150          Tottenham Hotspur       PERSON                 24            48
# 151                    Preston       PERSON                 33            48
# 152          Nottingham Forest          ORG                 48            48
# 153               Aaron Ramsey       PERSON                 47            47
# 154             Newport County          GPE                 46            46
# 155              Burton Albion       PERSON                 32            46
# 156                    Anfield          ORG                  1            46
# 157                 Cheltenham          GPE                 37            46
# 158                       Ajax       PERSON                  1            46
# 159              Jesse Lingard       PERSON                 46            46
# 160              Sergio Aguero       PERSON                 45            45
# 161                  Mansfield          GPE                 32            45
# 162                Claude Puel       PERSON                 45            45
# 163                Roy Hodgson       PERSON                 45            45
# 164                    Gerrard          ORG                  1            43
# 165                     Burton          GPE                  1            43
# 166                Inter Milan          ORG                 43            43
# 167                Jamie Vardy       PERSON                 43            43
# 168                        EFL          ORG                 42            42
# 169             Alexis Sanchez       PERSON                 42            42
# 170               Championship          ORG                 37            42
# 171                  Inverness          ORG                  1            42
# 172                  Dele Alli       PERSON                 42            42
# 173                     Forest       PERSON                  1            41
# 174                 Scunthorpe          GPE                 41            41
# 175                  Rotherham          GPE                 41            41
# 176                   Scotland          GPE                 41            41
# 177            Anthony Martial       PERSON                 40            40
# 178                     Bayern          ORG                 22            40
# 179                     Palace          FAC                  1            40
# 180                  Fleetwood          FAC                  2            40
# 181              Alvaro Morata       PERSON                 40            40
# 182                    Schalke       PERSON                 17            40
# 183              Wilfried Zaha       PERSON                 40            40
# 184                     Nantes          ORG                  1            39
# 185                    Falkirk          ORG                  4            39
# 186                    Wycombe          GPE                 37            39
# 187                Hudson-Odoi       PERSON                  3            39
# 188              Romelu Lukaku          ORG                  2            39
# 189                Exeter City          GPE                 39            39
# 190                  Port Vale          GPE                 34            38
# 191               Peterborough          GPE                 35            38
# 192               Chesterfield          GPE                 38            38
# 193                    Rodgers       PERSON                 38            38
# 194                      Milan          GPE                 38            38
# 195                      Spain          GPE                 37            37
# 196               Gary Neville       PERSON                 37            37
# 197                      China          GPE                 37            37
# 198                 Sadio Mane       PERSON                 36            36
# 199              Son Heung-min       PERSON                 36            36
# 200              Alex Ferguson       PERSON                 36            36
# 201                 Merseyside          GPE                 36            36
# 202         Accrington Stanley       PERSON                  8            35
# 203              Bradford City          GPE                 35            35
# 204                   Hamilton       PERSON                 30            35
# 205                     Wolves          ORG                 35            35
# 206                   Barnsley          ORG                  3            35
# 207                  Solskjaer          GPE                  3            34
# 208                  Brazilian          ORG                  1            34
# 209          Huddersfield Town       PERSON                 10            34
# 210                     Oxford          ORG                 18            34
# 211            Santiago Solari       PERSON                 34            34
# 212                    Sevilla          GPE                 34            34
# 213                Gareth Bale       PERSON                 34            34
# 214            Roberto Firmino       PERSON                 34            34
# 215           Manchester Citys          ORG                  1            34
# 216                  World Cup        EVENT                 34            34
# 217            Stamford Bridge          FAC                 34            34
# 218               Jadon Sancho       PERSON                 34            34
# 219                        AFC          ORG                 33            33
# 220                  Hibernian          ORG                 33            33
# 221                       Boro          ORG                  1            33
# 222          Christian Eriksen          ORG                  1            33
# 223                       Uefa          ORG                 23            33
# 224                    Spanish         NORP                 33            33
# 225                   AC Milan          ORG                 33            33
# 226        Ole Gunnar Solskjær       PERSON                 33            33
# 227    Wolverhampton Wanderers          ORG                  1            33
# 228       the Champions League        EVENT                 10            32
# 229              Cesc Fabregas       PERSON                 32            32
# 230           Sheffield United          ORG                  2            32
# 231                 Livingston          GPE                 25            32
# 232                    Morelos       PERSON                 18            32
# 233                   Charlton       PERSON                 14            32
# 234               Scottish Cup        EVENT                 30            31
# 235                   Arbroath          ORG                 29            31
# 236                   Southend          GPE                 30            31
# 237                      Dubai          GPE                 31            31
# 238        NEWCASTLE CHRONICLE          ORG                 31            31
# 239                 Eddie Howe       PERSON                 31            31
# 240              Saint-Germain       PERSON                 31            31
# 241                    Alisson          GPE                  1            30
# 242              Chris Hughton       PERSON                 30            30
# 243                  Eastleigh          GPE                 28            30
# 244                     Barnet          GPE                  3            30
# 245              Sutton United          GPE                 27            30
# 246                       Reds          ORG                 30            30
# 247            Tranmere Rovers          ORG                 30            30
# 248             Bernardo Silva       PERSON                 30            30
# 249              Milton Keynes       PERSON                 30            30
# 250                   Coventry          GPE                  2            29
# 251                Ross County       PERSON                 10            29
# 252                   Tranmere          ORG                 27            29
# 253                    Italian         NORP                 29            29
# 254               Swansea City          GPE                 29            29
# 255              Leyton Orient          GPE                  7            29
# 256                Declan Rice       PERSON                 29            29
# 257             FOOTBALLLONDON          GPE                 29            29
# 258         Manchester Uniteds       PERSON                  2            28
# 259                       Isco         NORP                  3            28
# 260                    Ronaldo       PERSON                 28            28
# 261                        Ayr          GPE                 20            28
# 262                  Harrogate          GPE                 27            28
# 263            West Ham United       PERSON                 10            28
# 264                      Italy          GPE                 28            28
# 265            Michy Batshuayi       PERSON                 28            28
# 266                    Warnock       PERSON                  4            28
# 267                 Colchester          GPE                 28            28
# 268                      Lawro       PERSON                 28            28
# 269            Carlisle United          GPE                 28            28
# 270                 RB Leipzig          GPE                 13            27
# 271                NGolo Kante          ORG                 23            27
# 272                  LEICESTER          GPE                 27            27
# 273                    Willian       PERSON                 27            27
# 274              Dundee United          ORG                  7            27
# 275                    Germany          GPE                 27            27
# 276                 FC Halifax          ORG                 27            27
# 277                Mike Ashley       PERSON                 26            26
# 278                 Villarreal          ORG                 16            26
# 279               Denis Suarez       PERSON                 26            26
# 280               Lincoln City          GPE                 18            26
# 281           Newcastle United       PERSON                  1            26
# 282                Richarlison       PERSON                 25            26
# 283                    Grimsby          GPE                  6            26
# 284                 Dundee Utd          ORG                 26            26
# 285               David de Gea       PERSON                 26            26
# 286            Kevin De Bruyne       PERSON                 26            26
# 287          Kepa Arrizabalaga       PERSON                 25            25
# 288              EXPRESS  STAR          ORG                 25            25
# 289                       City          GPE                 22            25
# 290                Javi Gracia       PERSON                 25            25
# 291               Boreham Wood          ORG                 25            25
# 292                 the FA Cup        EVENT                 25            25
# 293                      Dover          GPE                 25            25
# 294                   Bradford       PERSON                 12            25
# 295                  Braintree          GPE                 25            25
# 296                      Wales          GPE                 25            25
# 297               Derby County          GPE                 25            25
# 298                Troy Deeney       PERSON                 25            25
# 299                     French         NORP                 25            25
# 300                  Marseille          GPE                 25            25
# 301                 David Luiz       PERSON                 25            25
